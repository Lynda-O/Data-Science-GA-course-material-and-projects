# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Web Scraping: Solutions
#
# _Author: Dave Yerrington (SF)_
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Revisit how to locate elements on a webpage
# - Aquire unstructure data from the internet using Beautiful soup.
# - Discuss limitations associated with simple requests and urllib libraries
# - Introduce Selenium as a solution, and implement a scraper using selenium

# %% [markdown]
# ## Lesson Guide
#
# - [Introduction](#intro)
# - [Building a web scraper](#building-scraper)
# - [Retrieving data from the HTML page](#retrieving-data)
#     - [Retrieving the restaurant names](#retrieving-names)
#     - [Challenge: Retrieving the restaurant locations](#retrieving-locations)
#     - [Retrieving the restaurant prices](#retrieving-prices)
#     - [Retrieving the restaurant number of bookings](#retrieving-bookings)
#
#
# - [Introducting Selenium](#selenium)
#     - [Running JavaScript before scraping](#selenium-js)
#     - [Using regex to only get digits](#selenium-regex)
#     - [Challenge: Use Pandas to create a DataFrame of bookings](#challenge-pandas)
#     - [Auto-typing using Selenium](#selenium-typing)
#
#
# - [Summary](#summary)

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
#
# In this codealong lesson, we'll build a web scraper using urllib and BeautifulSoup. We will also explore how to use a headless browser called Selenium.
#
# We'll begin by scraping OpenTable's DC listings. We're interested in knowing the restaurant's **name, location, and price.**
#
# OpenTable provides all of this information on this given page: http://www.opentable.com/washington-dc-restaurant-listings
#
# Let's inspect the elements of this page to assure we can find each of the bits of information in which we're interested.
#
# ---

# %% [markdown]
# <a id="building-scraper"></a>
# ## Building a web scraper
#
# Now, let's build a web scraper for OpenTable using urllib and Beautiful Soup:

# %%
# import our necessary first packages
from bs4 import BeautifulSoup
import requests

# %%
# set the url we want to visit
url = "http://www.opentable.com/washington-dc-restaurant-listings"

# visit that url, and grab the html of said page
html = requests.get(url)

# %% [markdown]
# At this point, what is in html?

# %%
# .text returns the request content in Unicode
html.text[:500]
# Out:
# '           <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Restaurant Reservation Availability</title>    <meta  name="robots" content="noindex,nofollow" > </meta>     <link rel="shortcut icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon.ico" type="image/x-icon"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-16.png" sizes="16x16"/><l'

# %% [markdown]
# We will need to convert this html objct into a soup object so we can parse it using python and BS4

# %%
# convert this into a soup object
soup = BeautifulSoup(html.text, 'html.parser')
soup
# Out:
#  <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/> <title>Restaurant Reservation Availability</title> <meta content="noindex,nofollow" name="robots"> </meta> <link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-16.png" rel="icon" sizes="16x16"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-32.png" rel="icon" sizes="32x32"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-48.png" rel="icon" sizes="48x48"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-64.png" rel="icon" sizes="64x64"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-128.png" rel="icon" sizes="128x128"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//components.otstatic.com/components/favicon/1.0.6/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed"/><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["favicon"]="1.0.6";</script><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/> <link href="//media.otstatic.com/search-result-node/css/ot-kit.b88a5026.css" rel="stylesheet"/>
# <script>
#       window.OTDataLayer = [{"domain":1,"language":"en-US","metro_id":201,"page_name":"multisearchresultpage","user_type":"anonymous","visitor_status":"Logged Out"}];
#     </script>
# <script>window.OT = window.OT || {};
# window.OT.SRS = {
#   abTestingAnalytics: {"account":"2d65a94551a4a1caddd5a825a88698a89e19f2d5","hostname":"ac.opentable.com"},
#   disableRaven: false,
#   domainId: 1,
#   jsHeadVersion: "1.0.92",
#   lang: "en",
#   ocUrl: window.location.protocol + '//oc-registry.opentable.com/v2/',
#   requestId: "f7053305-0b7e-4c4b-94c4-14e4d57a204d"
# };
#
# window.OT.searchAutoComplete = {};
# window.OT.searchAutoComplete.ticketedRids = [681,1537,3334,7055,11065,29995,47119,53716,89905,100033,112846,114886,118765,140968,160504,185560,185773,210868,211918,212878,233239,252232,263128,267508,268867,270751,335149,347206,349942,984418,986635,986725];
#
# window.oc = window.oc || {};
# window.oc.conf = { globalParameters: { __ot_conservedHeaders: 'x2YPvT6POzqVVB9+77Ms1JVHKy6PLy+gSbvUPN43Rl476UN6TMIUpJnm/HgyWRNysvy538ye08Mqp5yngJiu7JaF6gNd4wvj0KUpKmMuHNuH5b+u5daUjkvzDWKDndTKCN58moZWRsaSwGZot3afWAkF+nwVC75sBRE6yzk1cKVUULkq+l3wNQraMC+/ZX4l8HlvMU8LEFM=' }};
# </script><!--[if lte IE 8]> <script src="//components.otstatic.com/components/js-head/1.0.92/min/ie8_compat.js"></script> <![endif]-->
# <!--[if IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.92/min/ie9_compat.js"></script> <![endif]--><script crossorigin="anonymous" src="//components.otstatic.com/components/js-head/1.0.92/min/bundle_head.js"></script><script>window.oc=window.oc||{};oc.conf=oc.conf||{};oc.conf.templates=(oc.conf.templates||[]).concat([{"type":"oc-template-es6","version":"1.0.1","externals":[]},{"type":"oc-template-jade","version":"7.0.0","externals":[{"global":"jade","url":"https://unpkg.com/oc-jade-legacy@1.11.1/runtime.js","name":"jade"}]},{"type":"oc-template-handlebars","version":"6.0.19","externals":[{"global":"Handlebars","url":"https://unpkg.com/handlebars@4.7.2/dist/handlebars.runtime.min.js","name":"handlebars"}]},{"type":"oc-template-react","version":"2.1.0","externals":[{"global":["Object","assign"],"url":"https://unpkg.com/es6-object-assign@1.1.0/dist/object-assign-auto.min.js","name":"Object.assign"},{"global":"PropTypes","url":"https://unpkg.com/prop-types@15.7.2/prop-types.min.js","name":"prop-types"},{"global":"React","url":"https://unpkg.com/react@16.9.0/umd/react.production.min.js","name":"react"},{"global":"ReactDOM","url":"https://unpkg.com/react-dom@16.9.0/umd/react-dom.production.min.js","name":"react-dom"}]},{"type":"ot-oc-template-react-email","version":"0.0.2","externals":[{"global":"PropTypes","url":"https://unpkg.com/prop-types@15.6.1/prop-types.min.js","name":"prop-types"},{"global":"React","url":"https://unpkg.com/react@16.2.0/umd/react.production.min.js","name":"react"},{"global":"ReactDOM","url":"https://unpkg.com/react-dom@16.2.0/umd/react-dom.production.min.js","name":"react-dom"}]}]);</script><script src="//components.otstatic.com/components/oc-client/0.48.15/src/oc-client.min.js" type="text/javascript"></script>
# <!--[if lte IE 9]> <script src="//components.otstatic.com/components/js-head/1.0.92/min/ie_jquery.js"></script> <![endif]--><script>window.optimizely = window.optimizely || [];</script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js-head"]="1.0.92";</script> <script src="//media.otstatic.com/search-result-node/js/generated/ie_compat.f9925470.js"></script>
# </head><body class="search com domain-com list has-results availability-search initial-load platform-unknown device-unknown page-type-0 appendGiftParameters appendRegionDescription appendReviewTerms customGoals disableMarketingForAffiliatePages domainCulture evaluateFilters sfx333 sfx333-1 sfx243 sfx243-2 sfx348 sfx348-1 sfx450 sfx450-1 sfx463 sfx463-1 sfx978 sfx978-1 sfx1267 sfx1267-1 sfx1388 sfx1388-1 sfx1499 sfx1499-1 sfx1149 sfx1149-1 genericExperiment listEvent otRequestId recordRestaurantCount stringifyExplanation userAgent SFX-368 sfx450"><script type="text/javascript">
#       if(!Object.getOwnPropertySymbols)
#           document.write('<script src="//media.otstatic.com/search-result-node/js/get-own-property-symbols-polyfill.js"><\/script>');
#     </script><div class="master-container" id="search-master-container"> <script>
#   if (window.Cypress) {
#     window.__TestGaCalls = [];
#     window.MapTrackGA = function(dataPoint) {
#       window.ga = function(_) {
#         window.__TestGaCalls.push(arguments);
#       }
#       var data = {};
#       data[dataPoint] = '1';
#       ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#     }
#   }
#   else {
#     window.MapTrackGA = function(dataPoint) {
#       if (typeof ga === 'function') {
#         var data = {};
#         data[dataPoint] = '1';
#         ga('gtm1.send', 'event', 'map_event', 'map_event', data);
#       }
#     }
#   }
# </script> <!--  Aria reference for this menu bar https://www.w3.org/TR/wai-aria-practices-1.1/examples/menubar/menubar-1/menubar-1.html#--><style>a.top-bar-nav-button.button.small.secondary{background-color:#247f9e}a.top-bar-nav-button.button.small.secondary:focus,a.top-bar-nav-button.button.small.secondary:hover{background-color:#154a5b}.icon-font{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb li.icon-visible a:before{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.breadcrumb{background-color:#fff!important;height:2rem;line-height:1.9rem;font-size:.75rem;border-top:1px solid rgba(0,0,0,.08)!important;border-bottom:none!important;padding:0 1.25rem}.breadcrumb:after,.breadcrumb:before{content:" ";display:table}.breadcrumb:after{clear:both}@media only screen and (min-width:64.0625em){.breadcrumb{padding:0 2.25rem}}.breadcrumb li{position:relative;display:block;float:left;margin:0 1rem 0 .35rem}.breadcrumb li.hidden{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.hidden{display:block}}.breadcrumb li.icon-visible{margin-left:0;height:100%;width:1.25rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible{margin-left:.35rem;width:auto}}.breadcrumb li.icon-visible a{display:block;width:100%;height:100%}.breadcrumb li.icon-visible a span{display:none}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a span{display:block}}.breadcrumb li.icon-visible a:before{content:"a";display:block;width:1.5rem;height:2rem;line-height:2rem;text-align:center;position:absolute;font-size:1rem}@media only screen and (min-width:40.0625em){.breadcrumb li.icon-visible a:before{display:none}}.breadcrumb li:first-child{margin-left:0}.breadcrumb li:last-child{margin-right:0}.breadcrumb li:last-child:after,.breadcrumb li:last-child:before{display:none}.breadcrumb li:after,.breadcrumb li:before{content:"";position:absolute;left:100%;margin-left:.25rem}.breadcrumb li:before{top:-1px;border-top:1rem solid transparent;border-bottom:1rem solid transparent;border-left:.6rem solid rgba(0,0,0,.2)}.breadcrumb li:after{top:0;border-top:.96rem solid transparent;border-bottom:.96rem solid transparent;border-left:.56rem solid #fff}.domain-comau .top-bar-nav-link.icon-location{line-height:55px}.domain-comau .top-bar-nav-link.icon-location:before{color:rgba(0,0,0,.12);font-size:18px;position:relative;top:4px;left:-2px}.domain-comau .with-location-picker .tab-bar-logo{margin-left:48px}.domain-comau .hamburger-menu .top-bar-nav-link{line-height:50px}.menu-drawer-left.sliding-menu .menu-close:after{font-family:icons;speak:none;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.menu-drawer-left.sliding-menu{position:fixed;background-color:unset;top:0;left:0;width:100%;height:100%;pointer-events:none;transition:background-color .25s ease-out}.menu-drawer-left.sliding-menu.menu-opened{background-color:rgba(0,0,0,.5);pointer-events:auto}.menu-drawer-left.sliding-menu.menu-opened:before{content:none}.menu-drawer-left.sliding-menu.menu-opened .menu-container{transform:translate3d(0,0,0)}.menu-drawer-left.sliding-menu .menu-container{width:220px;height:100%;max-height:initial;transition:transform .5s ease-out;transform:translate3d(-220px,0,0);opacity:1}.menu-drawer-left.sliding-menu .menu-container .menu-main{border-radius:0;box-shadow:none;width:100%;height:100%;margin:0;padding:3rem 0 .25rem 0}.menu-drawer-left.sliding-menu .menu-list-link{transition:color .15s ease-out;font-size:.875rem;padding:.5rem 1rem .5rem 1.5rem}.menu-drawer-left.sliding-menu .menu-list-link-primary{color:#60b2d0!important;border-bottom:1px solid rgba(0 ...
#   e.preventDefault();
#     var mainContentElement = jQuery('#search_control_container').first();
#     jQuery('html, body').animate({
#       scrollTop: (mainContentElement.offset().top)
#     }, 500);
#     // We can only focus a div if it has a tab index value. Set it to -1 so that we can focus it but we can't
#     // tab to it and so we don't disrupt the normal tab navigation flow
#     mainContentElement.attr('tabindex',-1).focus();
# });
# </script></div><div class="hamburger-pane" id="hamburger-pane"><div class="hamburger-pane__header"><div class="top-bar show-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"><a aria-hidden="false" aria-label="Toggle sidebar" class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#" tabindex="-1"><i class="icon-list font-size-medium"></i></a></li></ul></div><div class="tab-bar hide-for-medium-up"><ul class="hamburger-menu"><li class="top-bar-nav-li"><a aria-hidden="false" aria-label="Toggle sidebar" class="top-bar-nav-link js-toggle-hamburger" data-target="hamburger-pane" href="#" tabindex="-1"><i class="icon-list font-size-medium"></i></a></li></ul></div></div><div class="hamburger-pane__body"><ul class="hide-for-medium-up"><li><a aria-hidden="true" class="menu-list-link menu-list-link-primary" href="/my/registerpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2020-08-04%252019%253A00%26availability%3DincludeListings%26includeTicketedAvailability%3Dtrue%26userlongitude%3D-0.12%26userlatitude%3D51.50%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_up" tabindex="-1" title="Sign up">Sign up</a></li><li><a aria-hidden="true" class="menu-list-link menu-list-link-primary" href="/my/loginpopup?rp=https%3A%2F%2Fwww.opentable.com%2Fs%2F%3FmetroId%3D9%26enableSimpleCuisines%3Dtrue%26covers%3D2%26dateTime%3D2020-08-04%252019%253A00%26availability%3DincludeListings%26includeTicketedAvailability%3Dtrue%26userlongitude%3D-0.12%26userlatitude%3D51.50%26pageType%3D2&amp;srs=1" id="mobile_nav_sign_in" tabindex="-1" title="Sign in">Sign in</a></li></ul><div class="language-selector"><div class="languageSelectorLink"><div class="languageSelectorIcon"><div class="iconLanguageSelector"></div></div><div class="languageSelectorLabel">Language</div></div><div class="language-selector__menu menu menu-right"><div class="menu-container"><div class="menu-main"><div class="menu-section"><div class="language-selector__menu__list menu-list-selectors"><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="de" tabindex="-1">Deutsch</a><a aria-hidden="true" aria-selected="true" class="js-languages-list__link menu-list-link selected " data-lang="en" tabindex="-1">English</a><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="es" tabindex="-1">Español</a><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="fr" tabindex="-1">Français</a><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="it" tabindex="-1">Italiano</a><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="nl" tabindex="-1">Nederlands</a><a aria-hidden="true" class="js-languages-list__link menu-list-link" data-lang="ja" tabindex="-1">日本語</a></div></div></div></div></div></div><a aria-hidden="true" class="menu-list-link" href="https://help.opentable.com" tabindex="-1" target="_blank">Help</a><a aria-hidden="true" class="menu-list-link app-link" href="https://app.adjust.com/d8fpn6m?redirect=https://itunes.apple.com/app/id296581815?mt=8" tabindex="-1" target="_blank">iOS App</a><a aria-hidden="true" class="menu-list-link app-link" href="https://app.adjust.com/cok1xmg?redirect=https://play.google.com/store/apps/details?id=com.opentable" tabindex="-1" target="_blank">Android App</a></div></div><div class="js-toggle-hamburger" id="hamburger-overlay"></div><div class="site-header" id="header"><div class="header-promo-banner hide legacy" role="banner"><div class="header-promo-banner__inner"><div class="header-promo-banner__text">Now's the time to support your favorite restaurants.</div><a aria-hidden="false" class="header-promo-banner__link" href="https://blog.opentable.com/support-restaurants/" tabindex="0" target="_blank">Learn More</a></div><a class="header-promo-banner__close-container"></a></div><script>$(".header-promo-banner__close-container").click(function() ...
# </script><script>window.abtestGoalTracked = {};
# window.displaySearchFormHeader = false
# window.trackGoal = function trackGoal(goalName) {
#   if(window.analytics) {
#     if (window.debug_abtest_tracking) { console.log('Tracking goal: ', goalName); }
#
#     window.analytics.track(
#       'track_goal',
#       { goal_name: goalName },
#       function (err) { if(err) console.log(err); }
#     );
#   }
# };
#
# window.trackGoalOnce = function trackGoalOnce(goalName) {
#   if (!window.abtestGoalTracked[goalName]) {
#     window.abtestGoalTracked[goalName] = true;
#     window.trackGoal(goalName);
#   }
# }
#
# window.pageData = window.pageData || {};
# window.pageData.serialisedMetros = [{"n":"Atlanta / Georgia","d":"Atlanta / Georgia","m":16,"cn":"United States","cid":"US","did":1,"l":"en","u":"/atlanta-restaurants","r":6373,"lat":33.806193,"lon":-84.326474,"ma":[{"n":"Atlanta","m":50,"u":"/i/atlanta/atlanta-restaurants","r":2344},{"n":"Alpharetta / Roswell","m":199,"u":"/g/atlanta/alpharetta-roswell-restaurants","r":375},{"n":"Northeast Atlanta","m":1012,"u":"/g/atlanta/northeast-atlanta-restaurants","r":906},{"n":"South Atlanta","m":1015,"u":"/g/atlanta/south-atlanta-restaurants","r":561},{"n":"Northwest Atlanta","m":201,"u":"/g/atlanta/northwest-atlanta-restaurants","r":687},{"n":"Columbus","m":1759,"u":"/g/atlanta/columbus-restaurants","r":178},{"n":"Athens","m":2152,"u":"/g/atlanta/athens-restaurants","r":56},{"n":"Augusta","m":1084,"u":"/g/atlanta/augusta-restaurants","r":302},{"n":"N. GA Mountains / Wine Country","m":1390,"u":"/g/atlanta/n-ga-mountains-wine-country-restaurants","r":230},{"n":"Macon","m":1165,"u":"/g/atlanta/macon-restaurants","r":266},{"n":"Swainsboro","m":2092,"u":"/g/atlanta/swainsboro-restaurants","r":119},{"n":"Braselton","m":2701,"u":"/g/atlanta/braselton-restaurants","r":42},{"n":"Pine Mountain","m":2809,"u":"/g/atlanta/pine-mountain-restaurants","r":11},{"n":"Southwest Georgia","m":3319,"u":"/start/?m=16&mn=3319","r":2},{"n":"Statesboro","m":2950,"u":"/g/atlanta/statesboro-restaurants","r":90},{"n":"Thomasville","m":2521,"u":"/g/atlanta/thomasville-restaurants","r":204}],"f":true},{"n":"Baltimore / Maryland","d":"Baltimore Area","m":18,"cn":"United States","cid":"US","did":1,"l":"en","u":"/baltimore-restaurants","r":2997,"lat":39.281749,"lon":-76.595214,"ma":[{"n":"Baltimore","m":59,"u":"/i/baltimore/baltimore-restaurants","r":794},{"n":"Baltimore Suburbs","m":187,"u":"/g/baltimore/baltimore-suburbs-restaurants","r":1030},{"n":"Ocean City / Delaware Shore","m":1153,"u":"/g/baltimore/ocean-city-delaware-shore-restaurants","r":429},{"n":"Greater Annapolis","m":88,"u":"/g/baltimore/greater-annapolis-restaurants","r":254},{"n":"Eastern Shore","m":189,"u":"/g/baltimore/eastern-shore-restaurants","r":252},{"n":"Western MD","m":186,"u":"/g/baltimore/western-md-restaurants","r":190},{"n":"Chambersburg","m":2956,"u":"/g/baltimore/chambersburg-restaurants","r":48}],"f":true},{"n":"Boston / New England","d":"Boston / New England","m":7,"cn":"United States","cid":"US","did":1,"l":"en","u":"/boston-restaurants","r":11608,"lat":42.36488,"lon":-71.138978,"ma":[{"n":"Boston","m":47,"u":"/g/new-england/boston-restaurants","r":1608},{"n":"Boston Suburbs","m":206,"u":"/g/new-england/boston-suburbs-restaurants","r":2990},{"n":"Central MA","m":207,"u":"/g/new-england/central-ma-restaurants","r":680},{"n":"Western MA","m":208,"u":"/g/new-england/western-ma-restaurants","r":780},{"n":"Southern MA","m":406,"u":"/g/new-england/southern-ma-restaurants","r":524},{"n":"Cape Cod and the Islands","m":90,"u":"/g/new-england/cape-cod-and-the-islands-restaurants","r":616},{"n":"Maine","m":105,"u":"/g/new-england/maine-restaurants","r":1324},{"n":"Rhode Island","m":92,"u":"/g/new-england/rhode-island-restaurants","r":1106},{"n":"Vermont","m":114,"u":"/g/new-england/vermont-restaurants","r":814},{"n":"New Hampshire","m":131,"u":"/g/new-england/new-hampshire-restaurants","r":1166}],"f":true},{"n":"Chicago / Illinois","d":"Chicago / Illinois","m":3,"cn":"United States","cid":"US","did":1,"l":"en","u":"/chicago-restaurants","r":11198,"lat":41.879237,"lon":-87.84974,"ma":[{"n":"Chicago","m":11,"u":"/i/chicago/chicago-restaurants","r":3139},{"n":"North Suburbs","m":12,"u":"/g/chicago/north-suburbs-restaurants","r":931},{"n":"West Suburbs","m":15,"u":"/g/chicago/west-suburbs-restaurants","r":1230},{"n":"Northwest Suburbs","m":107,"u":"/g/chicago/northwest-suburbs-restaurants","r":1129},{"n":"Southwest Suburbs","m":198,"u":"/g/chicago/southwest-suburbs-restaurants","r":753},{"n":"Near West","m":1429,"u":"/g/chicago/near-west-restaurants","r":327},{"n":"South Suburbs","m":13,"u":"/g/ch ...
# window.pageData.metroId = 9;
# window.pageData.words = {
#   all: 'All {0}',
#   table: '',
#   usernameWelcome: 'Hello!'
# };
# window.pageData.headerSignedIn = false;
# window.forRestaurateursLink = {
#   onClick: function forRestaurateursLinkClicked() {
#     var url = 'https://restaurant.opentable.com/?utm_source=dinersite&utm_medium=referral&utm_campaign=topnav&Lead.LeadSource=DinerSite&Lead.Marketing_ID__c=topnav';
#     window.trackGoal('header_forRestaurateursLink_click');
#     window.open(url, '_blank');
#   }
# };
# window.allMetrosLink = {
#   onClick: function allMetrosLinkClicked() {
#     var url = '/all-metros';
#     if(true){
#       window.trackGoal('header_allMetrosLink_click');
#     }
#     window.open(url, '_blank');
#   }
# };
# window.promoBanner = {
#   onClick: function promoBannerClicked() {
#     var url = 'https://blog.opentable.com/support-restaurants/';
#     var eventName = 'covid_advisory_web_banner';
#     window.trackGoal(eventName);
#     window.OTDataLayer.push({
#       event: eventName
#     })
#     window.open(url, '_blank');
#   }
# }
# </script><script>$(".breadcrumb-link").click(function(c){window.trackGoal&&window.trackGoal("breadcrumb_link_clicked")});</script><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["header"]="2.2.30";</script> <div class="" id="search_control_container"> <div class="labels cf" id="search_control"> <div class="page-header cf"><div class="max-width-wrapper"><div class="page-header-content"> <div class="row"><div class="column"> <oc-component data-hash="fff6ca51de789e4cc6a7f6cbc1989fcd212dc14e" data-name="dtp" data-rendered="true" data-version="1.8.10" href="https://oc-registry.opentable.com/v2/dtp/^1.6.1?twoBoxSearch=false&amp;dateTime=2020-08-04T19%3A00&amp;metroId=9&amp;partySize=2&amp;showLargerParty=true&amp;showSearch=true&amp;searchPlaceholder=Location%2C%20Restaurant%2C%20or%20Cuisine&amp;theme=com&amp;showLoader=false&amp;spotlightButton=false&amp;otKit=false&amp;eventPrefix=&amp;renderCypressDataAttributes=false"><link href="//components.otstatic.com/components/dtp/1.8.10/dist/style.css" rel="stylesheet"/><style>@media (min--moz-device-pixel-ratio: 1.5), (-o-min-device-pixel-ratio: 3 / 2), (-webkit-min-device-pixel-ratio: 1.5), (min-device-pixel-ratio: 1.5), (min-resolution: 144dpi), (min-resolution: 1.5dppx) {
#     .tt-dropdown-menu:before {
#         background-image: url('//components.otstatic.com/components/dtp/1.8.10/img/menu-arrow@2x.png') !important;
#         background-size: 100%;
#     }
# }
# </style><div class="dtp-picker hide dtp-lang-en with-search single-search " data-event-prefix="" id="dtp-picker-20"><form class="dtp-picker-form false"><input name="timezoneOffset" title="timezoneOffset" type="hidden" value="-240"/><select class="party-size-picker hide"><option value="1">1 person</option><option selected="selected" value="2">2 people</option><option value="3">3 people</option><option value="4">4 people</option><option value="5">5 people</option><option value="6">6 people</option><option value="7">7 people</option><option value="8">8 people</option><option value="9">9 people</option><option value="10">10 people</option><option value="11">11 people</option><option value="12">12 people</option><option value="13">13 people</option><option value="14">14 people</option><option value="15">15 people</option><option value="16">16 people</option><option value="17">17 people</option><option value="18">18 people</option><option value="19">19 people</option><option value="20">20 people</option><option value="21">Larger party</option></select><input class="date-picker dtp-picker-selector" title="datePicker" type="text" value="2020-08-04"/><select class="time-picker hide"><option value="00:00">12:00 AM</option><option value="00:30">12:30 AM</option><option value="01:00">1:00 AM</option><option value="01:30">1:30 AM</option><option value="02:00">2:00 AM</option><option value="02:30">2:30 AM</option><option value="03:00">3:00 AM</option><option value="03:30">3:30 AM</option><option value="04:00">4:00 AM</option><option value="04:30">4:30 AM</option><option value="05:00">5:00 AM</option><option value="05:30">5:30 AM</option><option value="06:00">6:00 AM</option><option value="06:30">6:30 AM</option><option value="07:00">7:00 AM</option><option value="07:30">7:30 AM</option><option value="08:00">8:00 AM</option><option value="08:30">8:30 AM</option><option value="09:00">9:00 AM</option><option value="09:30">9:30 AM</option><option value="10:00">10:00 AM</option><option value="10:30">10:30 AM</option><option value="11:00">11:00 AM</option><option value="11:30">11:30 AM</option><option value="12:00">12:00 PM</option><option value="12:30">12:30 PM</option><option value="13:00">1:00 PM</option><option value="13:30">1:30 PM</option><option value="14:00">2:00 PM</option><option value="14:30">2:30 PM</option><option value="15:00">3:00 PM</option><option value="15:30">3:30 PM</option><option value="16:00">4:00 PM</option><option value="16:30">4:30 PM</option><option value="17:00">5:00 PM</option><option value="17:30">5:30 PM</option><option value="18:00">6:00 PM</option><option value="18:30">6:30 PM</option><option selected="selected" value="19:00">7:00 PM</option><option value="19:30">7:30 PM</option><option value="20:00">8:00 PM</option><option value="20:30">8:30 PM</option><option value="21:00">9:00 PM</option><option value="21:30">9:30 PM</option><option value="22:00">10:00 PM</option><option value="22:30">10:30 PM</option><option value="23:00">11:00 PM</option><option value="23:30">11:30 PM</option></select><div class="dtp-picker-search-container"><div class="dtp-picker-search-icon icon-search"></div><input class="dtp-picker-search" id="dtp-search-single-box" name="searchText" placeholder="Location, Restaurant, or Cuisine" title="Location, Restaurant, or Cuisine" type="text" value=""/></div><input class="button dtp-picker-button" type="submit" value="Find a Table"/></form><script>window.OT = window.OT || {};
# window.dtp_data = { theme: 'com', lang: 'en', ocUrl: 'na-srs.opentable.com/v2/', allowYesterday: false};
# </script><script src="//components.otstatic.com/components/dtp/1.8.10/dist/dtp.js?dtpId=dtp-picker-20"></script></div><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["dtp"]="1.8.10";</script></oc-component></div></div></div></div></div></div></div> <div class="modal-container table-categories-overlay" id="table-categories-overlay"><div class="modal-content"><div aria-labelledby="table-selector-label" aria-modal="true" class="modal-content-body table-selector" role="dialog"><div class="content-block table-selector-content" data-select-translation="Select" data-unavailable-translation="Unavailable"> <button aria-label="Cancel" class="modal-close" type="button"></button><div class="table-selector-header"><h3 id="table-selector-label" tabindex="-1">Please select a table type</h3></div><div class="category-rows"> <div class="category-row" data-category="default" data-standard-category="true"><div class="left category-name"> Standard</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=default" href="" target="_blank">Select <span class="off-screen">Standard</span></a></div> <div class="category-row" data-category="bar" data-standard-category="false"><div class="left category-name"> Bar</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=bar" href="" target="_blank">Select <span class="off-screen">Bar</span></a></div> <div class="category-row" data-category="counter" data-standard-category="false"><div class="left category-name"> Counter</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=counter" href="" target="_blank">Select <span class="off-screen">Counter</span></a></div> <div class="category-row" data-category="hightop" data-standard-category="false"><div class="left category-name"> High Top</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=highTop" href="" target="_blank">Select <span class="off-screen">High Top</span></a></div> <div class="category-row" data-category="outdoor" data-standard-category="false"><div class="left category-name"> Outdoor</div> <a class="right button category-button" data-href-addon="&amp;st=Standard&amp;papa=&amp;tc=outdoor" href="" target="_blank">Select <span class="off-screen">Outdoor</span></a></div> </div></div></div></div></div> <input id="_csrf" name="_csrf" type="hidden" value="X0C5Nbvw-CfuURYlwzpYE4AXlx9Bry38n-SU"><div class="overall-search-container" id="no-re-render-container"> <div class="filters-bar show-filter-content" id="filters-bar"><div class="max-width-wrapper js-sticky-target" id="sticker"><div class="row"><div class="column"><div class="visual_map_icon" data-view="map" role="button" tabindex="0"><div class="visual-button button"> Map</div></div> <div aria-label="filters" id="search_filters" role="search"> <ul class="filters-list"> </ul> </div></div></div></div></div> <div class="stack-selected-filters"> <div class="toggle-filter-bar"><div id="filter-toggle"><div class="filter-toggle-icon"></div> <span class="show-filter-text">Show filters</span> <span class="hide-filter-text">Hide filters</span></div></div><div class="selected-filters js-selected-filters full-width-wrapper"><div class="row"><div class="column" id="js-selected-filters-column"></div></div></div> <div aria-label="search results" class="search-results-container page-main-content max-width-wrapper" id="search_results_container" role="main"><div class="close-filters"></div> <div class="loader" id="loading_animation"><div class="spinner"></div><div aria-live="assertive" class="loader-content" id="loading_error_container"></div><span aria-live="assertive" id="loading_message" style="opacity: 0"></span></div> <div class="results-set results-table search-results" data-name="ResultsTable" id="search_results"> <div class="content-section-header"> <div class="flex-row-justify results-header">  ...
#   //TODO: Integrate this into react component during rewrite.  It toggles the .rest-row-offer-link from
#   // functionally expanding to see all offers, hiding the p.rest-row-offer-link and showing
#   // a.rest-row-offer-link which changes text from "See all specials" to "Learn More >" and links to the
#   // specials section on rest profile. Ticket: https://opentable.atlassian.net/browse/SV-2558
#   $('p.rest-row-offer-link').on('click', function(event) {
#     event.preventDefault();
#     $(this).closest('.hide-more-offers').removeClass('hide-more-offers').addClass('show-more-offers');
#   });
# </script> </div><div class="results-set results-map search-results" data-name="ResultsMap" id="search_results_map"> </div> <div id="row-service-results"></div></div></div><div class="right-sidebar" id="right-sidebar"></div></div> <style>.footer-base .affiliate-logo.logo-kayak{width:91px!important}.footer-base .priceline-links{margin-top:16px}#truste_banners{position:fixed;bottom:0;width:100%;max-width:100rem;display:flex;flex-direction:column-reverse;z-index:999}#truste_banners #truste-consent-track{position:static;bottom:auto}#truste-consent-content .truste-button2,#truste-consent-content .truste-messageColumn,#truste-consent-content2 .truste-messageColumn2,#truste-consent-content2 .truste-please-note{font-family:source-sans-pro,"Source Sans Pro","Helvetica Neue",Helvetica,Arial,sans-serif}#truste-consent-content .truste-button2{display:inline-block;width:auto}#truste-consent-track,#truste-consent-track2{background:rgba(51,51,51,.95)!important;z-index:999}#truste-consent-content .truste-buttonsColumn{margin:0}#truste-consent-content .truste-messageColumn{margin:23px 0}@media screen and (min-width:1025px){#truste-consent-content .truste-messageColumn{margin:23px 15px}}.footer-link-social{float:left;margin-right:8px;margin-bottom:8px;height:24px}@media screen and (min-width:641px) and (max-width:1024px){.footer-link-social{margin-right:4px;margin-bottom:4px}}.footer-link-social svg{width:24px;height:24px}.footer-link-social .social-icon-cutout{fill:#acacac}.footer-link-social:focus .social-icon-cutout,.footer-link-social:hover .social-icon-cutout{fill:#fff}.footer-link-social:last-child{margin-right:0}.footer-block a{cursor:pointer}.footer-container .button:focus{background:#999}.footer-container .restaurateurs-footer-link-block .button:focus{outline:#4d90fe auto 5px}</style><style>.footer-base .affiliate-logo {
#   background-image: none !important;
# }
# </style><div class="footer-container" id="footer" role="contentinfo"><div class="max-width-wrapper"><div class="email-signup footer-content-container"></div><script>$(function(){
#   $('.email-signup').html(oc.build({
#     baseUrl: OT.SRS.ocUrl,
#     name: 'oc_component_email_signup',
#     parameters: { language: 'en-US', metroId: '9' }
#   }));
#
#   oc.renderUnloadedComponents();
# });</script><div class="footer-content-container"><div class="footer-block"><h6>Discover</h6><ul><li><a href="#" onclick="onLinkClick('https://help.opentable.com/s/article/OpenTable-Dining-Rewards?language=en_US')">Dining Rewards</a></li><li><a href="https://www.opentable.com/m/private-dining-restaurants-in-north-america/">Private Dining</a></li><li><a href="https://www.opentable.com/m/best-restaurants-in-america-for-2017/">Top 100 Restaurants</a></li><li></li><li><a href="#" onclick="onLinkClick('https://help.opentable.com/s/article/How-do-I-make-reservations-for-others-with-an-Administrative-Professional-Account-1505261764797?language=en_US')">Reserve for Others</a></li><li><a href="https://opentable.com/nearme/all-cuisines-near-me">Cuisines Near Me</a></li><li><a href="https://opentable.com/nearme">Restaurants Near Me</a></li><li><a href="https://opentable.com/delivery">Delivery Near Me</a></li><li><a href="https://opentable.com/cuisines">Cuisines</a></li><li><a href="https://opentable.com/open">Restaurants Open Now</a></li></ul></div><div class="footer-block"><h6>OpenTable</h6><ul><li><a href="https://www.opentable.com/about/">About Us</a></li><li><a href="#" onclick="onLinkClick('https://blog.opentable.com')">Blog</a></li><li><a href="https://www.opentable.com/careers/">Careers</a></li><li><a href="#" onclick="onLinkClick('https://press.opentable.com')">Press</a></li></ul></div><div class="footer-block"><h6>More</h6><ul><li><a href="https://app.adjust.com/gh97ibu?redirect=https://itunes.apple.com/app/id296581815?mt=8" target="_blank">OpenTable for iOS</a></li><li><a href="https://app.adjust.com/dk33pts?redirect=https://play.google.com/store/apps/details?id=com.opentable" target="_blank">OpenTable for Android</a></li><li><a href="#" onclick="onLinkClick('https://dev.opentable.com')">Affiliate Program</a></li><li><a href="#" onclick="onLinkClick('https://help.opentable.com/s/?language=en_US')">Contact Us</a></li></ul></div><div class="footer-block"><h6>Our Sites</h6><ul><li></li><li><a href="https://www.opentable.jp">OpenTable.jp</a></li><li><a href="https://www.opentable.de">OpenTable.de</a></li><li><a href="https://www.opentable.es">OpenTable.es</a></li><li><a href="https://www.opentable.com.mx">OpenTable.com.mx</a></li><li><a href="https://www.opentable.ca">OpenTable.ca</a></li><li><a href="https://www.opentable.hk">OpenTable.hk</a></li><li><a href="https://www.opentable.ie">OpenTable.ie</a></li><li><a href="https://www.opentable.sg">OpenTable.sg</a></li><li><a href="https://www.opentable.nl">OpenTable.nl</a></li><li><a href="https://www.opentable.co.uk">OpenTable.co.uk</a></li><li><a href="https://www.opentable.com.au">OpenTable.com.au</a></li><li><a href="https://www.opentable.ae">OpenTable.ae</a></li><li><a href="https://www.opentable.co.th">OpenTable.co.th</a></li><li><a href="https://www.opentable.it">OpenTable.it</a></li></ul></div><div class="footer-block"><h6>Businesses</h6><div class="restaurateurs-footer-link-block"><a class="button small with-arrow text-arrow-right" href="#" onclick="onLinkClick('https://restaurant.opentable.com/?utm_source=dinersite&amp;utm_medium=referral&amp;utm_campaign=topnav&amp;Lead.LeadSource=DinerSite&amp;Lead.Marketing_ID__c=topnav')">Delight more diners</a><a class="button small with-arrow text-arrow-right" href="#" onclick="onLinkClick('https://openforbusiness.opentable.com')">Open for Business Blog</a></div><h6>Join us on</h6><div class="footer-social-links"><a class="footer-link-social" href="#" onclick="onLinkClick('https://twitter.com/opentable')" title="twitter"><svg height="24px" version="1.1" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g class="social-icon-cutout" fill="#D8D8D8" transform="translate(-67.000000, -79.000000)">
# <path d="M79,103 C72.372583,103 67,97.627417 67,91 C67,84.372583 72.372583,79 79,79 C85.627417,79 91,84.372583 91,91 C91,97.627417 85.627417,103 79,103 Z M76.40272,97.375 C81.68576,97.375 84.57536,92.9983565 84.57536,89.202951 C84.57536,89.07864 84.57536,88.954889 84.56696,88.8316979 C85.1291056,88.4251173 85.6143591,87.9216961 86,87.3450054 C85.4757723,87.5772776 84.9196644,87.7296016 84.35024,87.7968927 C84.9498566,87.4379486 85.3986292,86.8733918 85.61304,86.2082876 C85.0492082,86.5428384 84.4323618,86.7786131 83.78912,86.9054372 C82.8987664,85.9587664 81.4840028,85.7270654 80.3381476,86.3402588 C79.1922923,86.9534522 78.600314,88.2590417 78.89416,89.5249277 C76.5846616,89.4091558 74.4329064,88.318396 72.9744,86.5241048 C72.2120287,87.8364509 72.6014332,89.5153297 73.86368,90.3581475 C73.4065751,90.3446007 72.9594364,90.2213007 72.56,89.9986535 C72.56,90.0104126 72.56,90.0227317 72.56,90.0350508 C72.5603742,91.402244 73.5241808,92.5798065 74.8644,92.8505272 C74.441527,92.9658453 73.9978451,92.9827025 73.56744,92.8998037 C73.9437308,94.0697958 75.0220818,94.8713 76.25096,94.8943794 C75.2338516,95.6936835 73.9773933,96.1275937 72.68376,96.1262903 C72.455226,96.1258516 72.2269143,96.1120155 72,96.0848533 C73.3135561,96.9277472 74.8419515,97.3748415 76.40272,97.3727602 L76.40272,97.375 Z" id="twitter"></path>
# </g>
# </g>
# </svg><img alt="twitter" class="hide"/></a><a class="footer-link-social" href="#" onclick="onLinkClick('https://www.facebook.com/opentable')" title="facebook"><svg height="24px" version="1.1" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g class="social-icon-cutout" fill="#D8D8D8" transform="translate(-99.000000, -79.000000)">
# <path d="M111,103 C104.372583,103 99,97.627417 99,91 C99,84.372583 104.372583,79 111,79 C117.627417,79 123,84.372583 123,91 C123,97.627417 117.627417,103 111,103 Z M111.128985,99 L111.128985,92.1664955 L113.465487,92.1664955 L113.81612,89.4929198 L111.128985,89.4929198 L111.128985,87.7880309 C111.128985,87.0130814 111.345968,86.4892156 112.470194,86.4892156 L113.894737,86.4892156 L113.894737,84.1039211 C113.200025,84.0327917 112.501967,83.9981284 111.80352,84.0000779 C109.739033,84.0000779 108.325496,85.239997 108.325496,87.5245481 L108.325496,89.4929198 L106,89.4929198 L106,92.1664955 L108.328641,92.1664955 L108.328641,99 L111.128985,99 Z" id="facebook"></path>
# </g>
# </g>
# </svg><img alt="facebook" class="hide"/></a><a class="footer-link-social" href="#" onclick="onLinkClick('https://www.linkedin.com/company/opentable')" title="linkedin"><svg height="24px" version="1.1" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g class="social-icon-cutout" fill="#D8D8D8" transform="translate(-163.000000, -79.000000)">
# <path d="M175,103 C168.372583,103 163,97.627417 163,91 C163,84.372583 168.372583,79 175,79 C181.627417,79 187,84.372583 187,91 C187,97.627417 181.627417,103 175,103 Z M182,97 L182,92.2691991 C182,89.9454731 181.493447,88.16 178.748516,88.16 C177.429853,88.16 176.546684,88.8749926 176.18428,89.5528297 L176.14672,89.5528297 L176.14672,88.3738953 L173.55,88.3738953 L173.55,97 L176.25737,97 L176.25737,92.733141 C176.25737,91.6084335 176.472579,90.5178689 177.881589,90.5178689 C179.272327,90.5178689 179.290599,91.8042531 179.290599,92.8044394 L179.290599,97 L182,97 Z M170.561511,87.12 C171.420846,87.12 172.12,86.420846 172.12,85.5594963 C172.12,84.699154 171.420846,84 170.561511,84 C169.697139,84 169,84.699154 169,85.5594963 C169,86.420846 169.697139,87.12 170.561511,87.12 Z M169.26,97 L171.99,97 L171.99,88.29 L169.26,88.29 L169.26,97 Z" id="linkedin"></path>
# </g>
# </g>
# </svg><img alt="linkedin" class="hide"/></a><a class="footer-link-social" href="#" onclick="onLinkClick('https://www.instagram.com/opentable')" title="instagram"><svg height="24px" version="1.1" viewbox="0 0 24 24" width="24px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <g class="social-icon-cutout" fill="#D8D8D8" transform="translate(-195.000000, -79.000000)">
# <path d="M207,103 C200.372583,103 195,97.627417 195,91 C195,84.372583 200.372583,79 207,79 C213.627417,79 219,84.372583 219,91 C219,97.627417 213.627417,103 207,103 Z M207.000014,84 C205.098914,84 204.860533,84.0080581 204.113909,84.0421244 C203.368841,84.0761073 202.859986,84.1944502 202.414734,84.3675048 C201.954422,84.5463668 201.564049,84.7857201 201.174871,85.1748706 C200.78572,85.564049 200.546367,85.9544221 200.367505,86.414734 C200.19445,86.8599856 200.076107,87.3688406 200.042124,88.113909 C200.008058,88.8605334 200,89.0989141 200,91.0000139 C200,92.9010859 200.008058,93.1394666 200.042124,93.886091 C200.076107,94.6311594 200.19445,95.1400144 200.367505,95.585266 C200.546367,96.0455779 200.78572,96.435951 201.174871,96.8251294 C201.564049,97.2142799 201.954422,97.4536332 202.414734,97.632523 C202.859986,97.8055498 203.368841,97.9238927 204.113909,97.9578756 C204.860533,97.9919419 205.098914,98 207.000014,98 C208.901086,98 209.139467,97.9919419 209.886091,97.9578756 C210.631159,97.9238927 211.140014,97.8055498 211.585266,97.632523 C212.045578,97.4536332 212.435951,97.2142799 212.825129,96.8251294 C213.21428,96.435951 213.453633,96.0455779 213.632523,95.585266 C213.80555,95.1400144 213.923893,94.6311594 213.957876,93.886091 C213.991942,93.1394666 214,92.9010859 214,91.0000139 C214,89.0989141 213.991942,88.8605334 213.957876,88.113909 C213.923893,87.3688406 213.80555,86.8599856 213.632523,86.414734 C213.453633,85.9544221 213.21428,85.564049 212.825129,85.1748706 C212.435951,84.7857201 212.045578,84.5463668 211.585266,84.3675048 C211.140014,84.1944502 210.631159,84.0761073 209.886091,84.0421244 C209.139467,84.0080581 208.901086,84 207.000014,84 Z M207.000014,85.261259 C208.869076,85.261259 209.090479,85.2684002 209.828601,85.3020774 C210.511094,85.3331984 210.881738,85.4472343 211.1284,85.5430979 C211.455142,85.6700824 211.688326,85.8217692 211.933265,86.0667353 C212.178231,86.3116737 212.329918,86.5448584 212.456902,86.8716004 C212.552766,87.1182615 212.666802,87.4889062 212.697923,88.1713993 C212.7316,88.9095211 212.738741,89.1309242 212.738741,91.0000139 C212.738741,92.8690758 212.7316,93.0904789 212.697923,93.8286007 C212.666802,94.5110938 212.552766,94.8817385 212.456902,95.1283996 C212.329918,95.4551416 212.178231,95.6883263 211.933265,95.9332647 C211.688326,96.1782308 211.455142,96.3299176 211.1284,96.4569021 C210.881738,96.5527657 210.511094,96.6668016 209.828601,96.6979226 C209.09059,96.7315998 208.869215,96.738741 207.000014,96.738741 C205.130785,96.738741 204.909438,96.7315998 204.171399,96.6979226 C203.488906,96.6668016 203.118262,96.5527657 202.8716,96.4569021 C202.544858,96.3299176 202.311674,96.1782308 202.066735,95.9332647 C201.821797,95.6883263 201.670082,95.4551416 201.543098,95.1283996 C201.447234,94.8817385 201.333198,94.5110938 201.302077,93.8286007 C201.2684,93.0904789 201.261259,92.8690758 201.261259,91.0000139 C201.261259,89.1309242 201.2684,88.9095211 201.302077,88.1713993 C201.333198,87.4889062 201.447234,87.1182615 201.543098,86.8716004 C201.670082,86.5448584 201.821769,86.3116737 202.066735,86.0667353 C202.311674,85.8217692 202.544858,85.6700824 202.8716,85.5430979 C203.118262,85.4472343 203.488906,85.3331984 204.171399,85.3020774 C204.909521,85.2684002 205.130924,85.261259 207.000014,85.261259 Z M207.000014,93.3333333 C205.71133,93.3333333 204.666667,92.2886704 204.666667,91.0000139 C204.666667,89.7113296 205.71133,88.6666667 207.000014,88.6666667 C208.28867,88.6666667 209.333333,89.7113296 209.333333,91.0000139 C209.333333,92.2886704 208.28867,93.3333333 207.000014,93.3333333 Z M207.000014,87.4054077 C205.014749,87.4054077 203.405408,89.0147487 203.405408,91.0000139 C203.405408,92.9852513 205.014749,94.5945923 207.000014,94.5945923 C208.985251,94.5945923 210.594592,92.9852513 210.594592,91.0000139 C210.594592,89.0147487 208.985251,87.4054077 207.000014,87.4054077 Z M211.576624,87.2633906 C211.576624,86.7994665 211.200534,86.4233756 210.736609,86.4233756 C210.272713,86.4233756 209.896622,86.79 ...
# </g>
# </g>
# </svg><img alt="instagram" class="hide"/></a></div></div></div><div class="footer-content-container"><div class="footer-base"><a class="footer-base-link" href="/legal/privacy-policy">Privacy Policy</a><a class="footer-base-link" href="/legal/terms-and-conditions">Terms of Use</a><a class="footer-base-link" href="/legal/cookie-policy">Cookies and Interest-Based Ads</a><a class="footer-base-link" href="/user/legal/personal-data">Do Not Sell My Info (California)</a><a class="footer-base-link" id="teconsent" style="display: none;"></a><br/><span class="footer-copyright">Copyright © 2020 OpenTable, Inc. 1 Montgomery St Ste 700, San Francisco CA 94104 - All rights reserved.</span></div><div class="footer-base ot-affiliates"><span>OpenTable is part of Booking Holdings, the world leader in online travel and related services.</span><br/><div class="priceline-links"><img alt="Booking logo" class="affiliate-logo logo-booking" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/booking_logo.png"/><img alt="Priceline logo" class="affiliate-logo logo-priceline" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/priceline_logo.png"/><img alt="KAYAK logo" class="affiliate-logo logo-kayak" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/kayak_logo.png"/><img alt="Agoda logo" class="affiliate-logo logo-agoda" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/agoda_logo.png"/><img alt="Rentalcars logo" class="affiliate-logo logo-rentalcars" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/rentalcars_logo.png"/><img alt="OpenTable logo" class="affiliate-logo logo-opentable" crossorigin="anonymous" src="//components.otstatic.com/components/footer/1.1.21/img/opentable_logo.png"/></div></div></div></div></div><div id="truste_banners"><div id="consent_blackbar"></div></div><script>window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
# // NOTE: This was done for SEO purposes. See https://github.com/opentable/oc-core-components/pull/469
# // The onclick handler prevents seo bots from going to certain links. `href="#"` a11y fix was added to links using
# // the onClick event so that screen readers and assistive devices can properly tab to them while SEO bots see it
# // as a self link and don't crawl to it.
# var onLinkClick = function(url) {
#   window.open(url, '_blank');
# ...
#       },
#       Search: {
#         FreeTextSearch: {"Context":"From the {0}","Description":"restaurant description","Menu":"menu","NoResultsMessage":"Sorry, we couldn't find any results for {0}. Try checking your spelling or using less specific keywords.","Reviews":"reviews"},
#         Map: {"Navigation_Next":"Next","Navigation_Previous":"Prev","SearchWithin":"Only search for restaurants within","Title":"Showing nearest {0} restaurants","UserPinTitle":"Drag and drop me to search near a different area"},
#         Results: {"AboveMaxPartySize":"Your party size is larger than this restaurant's limit for online bookings.","BelowMinPartySize":"You have not entered the minimum party size for online bookings at this restaurant.","BlockedDay":"Online bookings are not available on this date at this restaurant.","EarlyCutoff":"Your requested date exceeds the minimum advance booking limit for this restaurant.","FilteredBy":"Filtered By","FilteredBy_Cuisine":"Cuisine","FilteredBy_Location":"Location","FilteredBy_OfferType":"Specials","FilteredBy_PopOnly":"1,000 Pt times","FilteredBy_Price":"Price","NotActive":"Online reservations for now have been suspended. If you would like to make a reservation please contact the restaurant directly.","NotFarEnoughInAdvance":"You must make bookings at least 5 minutes in advance of the time at this restaurant.","NoTimesExist":"No tables are available within 2.5 hours of your request.","Offline":"This restaurant is unable to confirm reservations online at the moment. Therefore, please contact the restaurant directly.","RestoreSearch":"Restore last search","SameDayCutoff":"This Restaurant has a cut off time for same day reservations and this has now passed.","SeeAllOffers":"See all specials","TooFarInAdvance":"Your requested date exceeds the maximum advance booking limit for this restaurant.","BlockedTimesExist":"Please accept our apologies on behalf of {0}. Online bookings are not available on this date at this restaurant.","AltTag":"Photo of {0} Restaurant"},
#         Strings: {"NoSearchResults_MetroLink":"Return to the {0} homepage","NoSearchResults_MetroListLink":"Browse the list of all {0} restaurants","NoSearchResults_NoMatch_Message":"Unfortunately there are no OpenTable restaurants that meet all the criteria you specified.","NoSearchResults_NoMatch_Message_Freetext":"There are no restaurants with availability within 30 miles of your search.","NoSearchResults_NoMatch_Title":"We did not find a match for your search","NoSearchResults_Or":"or","NoSearchResults_OtherSuggestions":"Other suggestions","NoSearchResults_OtherSuggestionsMessage":"Or deselect any checkmarked box under \"Narrow results\" to broaden your search","NoSearchResults_StartOverButton":"Start over","NoSearchResults_UndoLastFilterButton":"Undo my last filter action"},
#         TableCategories: {"ModalTitle":"Please select a table type","TooltipTitle":"Seating Options","DescriptionTitle":"Seating","Select":"Select","Unavailable":"Unavailable","Categories":{"default":"Standard","bar":"Bar","counter":"Counter","hightop":"High Top","outdoor":"Outdoor"}},
#         Tabs: {"List":"List","Map":"Map"}
#       },
#       Redesign: {
#         Filters: {"All_Cuisines":"All Cuisines","All_Locations":"All Locations","All_Offers":"All Specials","All_Prices":"All Prices","All_TableCategories":"All Seating Options","All_Tags":"All Top Rated","DismissFilters":"Dismiss filters","Label_AllDiningOptions":"All dining options","Label_Apply":"Apply","Label_Cancel":"Cancel","Label_FilterBy_Cuisine":"Filter by Cuisine","Label_FilterBy_OfferType":"Filter by Points & Specials","Label_FilterBy_Price":"Filter by Price","Label_FilterBy_Range":"Choose a Range","Label_Sort":"Sort","Label_Sort_Distance":"Distance","Label_Sort_Newest":"Newest","Label_Sort_Popularity":"Best Match","Label_Sort_Popularity_Mobile":"Popular","Label_Sort_Rating":"Highest Rated","Label_Sort_Rating_Mobile":"Rating","Title_Cuisines":"Cuisine","Title_DiningType":"Dining Options","Title_Featured":"Featured","Title_Filters":"Filters","Title_Locations":"Location","Title_Neighborhoods":"Neighborhoods","Title_OfferTypes":"Specials","Title_PopOnly":"1,000 Point Times","Title_Price":"Price","Title_Range":"Range:","Title_RefineYourSearch":"Refine Your Search","Title_Regions":"Regions","Title_TableCategories":"Seating Options","Title_Tags":"Top Rated","Title_Time":"Time"},
#         Strings: {"CopyrightFormat":"Copyright &copy; {0} OpenTable, Inc. All rights reserved.","CurrencySymbol":"$","DefaultReviewerName":"OpenTable Diner","InterimLoader":"Finding tables...","Label_Next":"Next","Label_Previous":"Previous","Label_Sort":"Sort","Label_SortBy":"Sort by","Label_Sort_Popularity":"Best Match","Label_Sort_Rating":"Highest Rated","Label_TopOffer":"Top special:","Label_TopExperience":"Top experience:","Label_DeliveryPartners":"Delivery partners","Label_TakeoutPartners":"Takeout","LearnMore":"Learn more","Less":"Less","MapFooterLink_Privacy":"Privacy Policy","MapFooterLink_Terms":"Terms of Use","More":"More","PointsText":"+ {0} pts","Recently_Viewed":"Recently viewed","Reserve_Dinner":"Reserve for Dinner","Reserve_Lunch":"Reserve for Lunch","Reserve_Now":"Reserve","SearchPlaceholder":"Location, Restaurant, or Cuisine","SearchPlaceholderNoCuisine":"Location or Restaurant","See_More":"See more","SimilarTo":"Similar to {0}","SorrySimilar":"Sorry, we could not find any similar restaurants for {0} at this time","Tags":"Top rated for ","TimeslotAvailability_Single":"Hurry, we only have 1 timeslot left!","TimeslotAvailability_Multiple":"Hurry, we only have {0} timeslots left!","TimeslotAvailability_Single_2":"You're in luck! We still have 1 timeslot left.","TimeslotAvailability_Multiple_2":"You're in luck! We still have {0} timeslots left.","TimeslotLegend_Experience":"Experience","TimeslotLegend_Experiences":"Experiences","TimeslotLegend_Offer":"Special","TimeslotLegend_Offers":"Specials","TimeslotAccessibleDescription":"Reserve at {0}","TimeslotAccessibleModalWarning":"Opens a modal dialog"},
#         Results: {"Header_Area":"Neighborhood","Header_Availability":"Availability (click time to reserve)","Header_Cuisine":"Cuisine","Header_Name":"Restaurant Name","Header_Name_Short":"Name","Header_Popularity":"Popularity","Header_Price":"Price","Header_Ratings":"Ratings","ListingsMessage":"Unfortunately, this restaurant is not on the OpenTable reservation network. To see if they take reservations and have availability, you will need to call the restaurant directly or visit their website.","DinerRecommendations":"Diner recommendations","ViewMenuLink":"View Menu","NextAvailableButton":"Find next available","PopTitle":"{0} table with 1,000-Point times available","PopTitle_Plural":"{0} tables with 1,000-Point times available","RequestReservation":"Request Reservation","Review":"Review","Reviews":"{0} review","ReviewsComingSoon":"Reviews coming soon","Reviews_Plural":"{0} reviews","Reviews_Good":"Good","Reviews_Very_Good":"Very Good","Reviews_Excellent":"Excellent","Reviews_Awesome":"Awesome","Reviews_Exceptional":"Exceptional","SeeAllOffers":"See all specials","Timeslot1000Points":"1,000pts","Title_Availability":"{0} table available for {1} on {2}, at {3}","Title_Availability_Plural":"{0} tables available for {1} on {2}, at {3}","Title_Exact_Match":"Exact Match","Title_Promos":"{0} Restaurant","Title_NoAvailability":"Tables with no availability for {1} on {2}, at {3}","Title_NoAvailability_Plural":"Tables with no availability for {1} on {2}, at {3}","Title_Regions_Description":"in {0}","Title_Search_Summary":"You searched for {0} in {1}","WithAvailabilityLink":"{0} additional table available","WithAvailabilityLink_Plural":"{0} additional tables available","Header_Distance":"Distance","FeaturedPopTitle":"Restaurant with 1,000-Point times available","FeaturedPopTitle_Plural":"Restaurants with 1,000-Point times available","Header_Sorted_by":"Sorted by:","IncludeInterspercedAvailabilityLink":"Repeat this search showing omitted results","IncludeInterspercedAvailabilityText":"Some restaurants were not shown as they do not have availability matching your search criteria","About1000PointRestaurants":"About 1,000-Point Restaurants","AboutBonusPointRestaurants":"About Bonus Points","PopTooltipContent1":"Earn rewards fast with Bonus Points. Every time you dine with OpenTable, you earn 100 points. When you dine at <strong>select bonus point restaurants</strong>, you earn 500 or 1,000 points.","PopTooltipContent2":"Since you’re eligible for rewards after 2,000 points, just a few Bonus Point reservations you honor will get you there. Points are redeemable for dining rewards or Amazon gift cards.","Related_Searches":"Related searches","RestaurantsYouMayLike":"Restaurants you may also like","SingleSearchResults":"Search result for {0}","Title_IntersperseAvailability_Plural":"{0} tables for {1} on {2}, at {3}","Title_DateLessSearch":"{0} tables available","Title_DateLessSearch_Singular":"{0} table available","Title_Promos_Plural":"{0} Restaurants","Explanation_BecauseYouLiked":"Because you liked {0}","Explanation_SimilarExperienceTo":"Similar experience to {0}","Explanation_SimilarMenuTo":"Similar menu to {0}","ViewAffiliatedRestaurantsLink":"View affiliated restaurants","Title_Consumer_Disclosure":"How are Featured results ranked","Tooltip_Label_Consumer_Disclosure":"Tooltip info for how search results are ranked","Popover_Consumer_Disclosure":"The default order for search results reflects a number of factors, including table availability, restaurant location, search criteria, and restaurant reviews and ratings. In addition, payment made by a restaurant to OpenTable is also a factor for the relative ordering of restaurants.","Tooltip_Label_Google_Places":"Tooltip info for photos {0}","Takeout_OrderRestaurant":"Call the restaurant for a takeout service","Delivery_OrderDelivery":"Order delivery service with out partner, {0}","Popover_Google_Places_Label":"Photos from this restaurant are ","Popover_Google_Places_AltText":"Photos from this resta ...
#         NoResults: {"Heading":"We did not find a match for your search","OtherSuggestionsHeading":"Other suggestions","OtherSuggestionsMessage":"Or deselect any checked filters to broaden your search"},
#         PremiumAccess: {"Tables":"Premium Access Tables","CalloutText":"Popular restaurants have set aside tables to offer our most loyal diners. You can book these tables through OpenTable by redeeming your Dining Points.","GotIt":"Got It","LearnMore":"Learn More","BookText":"This premium table has been set aside for loyal diners like you"}
#       },
#       PopRestaurantList: {
#         Strings: {"PageTitleFormat":"{0} restaurants dining rewards","PageDescription":"Earn free meals faster by making a 1,000 point reservation at one of these great restaurants. Once you reach 2,000 points you'll be able to redeem them for a $20 dining cheque!","PopScheduleHeading":"1,000 point tables","SearchBigHeadingFormat":"Make a 1,000-Point Reservation in {0}","PointsAboutText":"Get rewarded for dining.<br />Faster, with 1,000-point tables."}
#       },
#     }
#   };
# </script><script src="//media.otstatic.com/search-result-node/js/generated/bundle_views_redesign.3d72897d.js"></script> <script id="marketing-data-layer-scripts">
#     window.OT = window.OT || {};
#     window.OT.MarketingDataLayer = {"language":"en-US","page_name":"search","time_search":"5:13:48 PM","date_search":"2020-08-04T17:13:48+00:00","current_date":"2020-08-04T17:13:48.192Z","day_type":"weekday","searchgeo_longlat":"139.729166,139.729166","logged_in_status":"logged_out","user_primary_metro_id":201,"user_origin":201};
#   </script> <script id="srs-scripts">window.OT = window.OT || {};
# window.OT.SRS = window.OT.SRS || {};
#
# window.OT.SRS.calendarStartsSunday = true;
# window.OT.SRS.dateFormatJS = "mmm d, yyyy";
# window.OT.SRS.disableRecaptchaV3 = false;
# window.OT.SRS.disableSignal = false;
# window.OT.SRS.jsVersion = "1.9.4";
# window.OT.SRS.location = "//components.otstatic.com/components/js/1.9.4/";
# window.OT.SRS.recaptchaV3Key = "6Ldcf5gUAAAAANNm2f66Vs0s7G5muVGh9j17Neex";
# window.OT.SRS.secure_domain = "www.opentable.com";
# window.OT.SRS.srsUrl = "//na-srs.opentable.com";
# window.OT.SRS.timeFormatJS = "h:mm A";
# window.OT.SRS.today = "Today";
# window.OT.SRS.tomorrow = "Tomorrow";
# window.OT.SRS.datePickerLocalization = null;
# window.OT.SRS.brightTagSrc = "//srsv2.s3.amazonaws.com/components/js/1.9.4/min/brighttag.html";
# window.OT.SRS.fbFrame = {"src":"//srsv2.s3.amazonaws.com/components/js/1.9.4/min/imgframe.html","root":"https://www.facebook.com/tr?id=725308910857169","fields":{"cd[content_type]":"hotel","eid":"f7053305-0b7e-4c4b-94c4-14e4d57a204d","ud[external_id]":"551686743ab251cd1a69817ceca653949d337782c72cbbf344bc3fa3b0b56006"}};
# window.abGlobal10Variant = 0;
# window.includeImpressionsFix = true;
# </script><style type="text/css">.grecaptcha-badge {
#   visibility: hidden;
# }
# </style><script crossorigin="anonymous" src="//components.otstatic.com/components/js/1.9.4/min/bundle_common.js"></script><noscript><iframe display="none" height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MJTRF6F" visibility="hidden" width="0"></iframe></noscript><script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["js"]="1.9.4";</script> <script src="//media.otstatic.com/search-result-node/js/generated/bundle_common_redesign.940e5cf8.js"></script>
# <script src="//media.otstatic.com/search-result-node/js/generated/bundle_redesign.38c988ae.js"></script>
# <script src="//media.otstatic.com/search-result-node/js/generated/commonjs-bundle.a44ff95c.js"></script>
# <script src="//media.otstatic.com/search-autocomplete-client/js/one-box-search-14.1.2.min.js"></script>
# <!-- Experiments -->
# <script>
#   /**
#    * Server side logic can be found in:
#    * app/deadCodeDection
#    */
#   function initDeadCodeDetection() {
#     window.openGraves = [];
#     setInterval(function () {
#       if (window.openGraves.length) {
#         // clone array
#         var data = window.openGraves.slice();
#         // empty array.
#         window.openGraves.splice(0);
#
#         var qs = data.map(function(val){ return 'g=' + encodeURIComponent(val); });
#         navigator.sendBeacon('/s/dead-code?' + qs.join('&'));
#
#       }
#     }, 10000)
#     window.tombstone = function tombstong(key) {
#       window.openGraves.push(key);
#     }
#     window.addEventListener("unload", function() {
#       if (window.openGraves.length) {
#         var data = window.openGraves;
#         var qs = data.map(function(val){ return 'g=' + encodeURIComponent(val); });
#         navigator.sendBeacon('/s/dead-code?' + qs.join('&'));
#       }
#     });
#   }
#   initDeadCodeDetection();
#
#   /* Please do not remove this tombstone: */
#   tombstone('x-client');
#
#   OT.Common.init();
#   OT.Redesign.init();
#   OT.Autocomplete.init();
#   OT.BestAnalytics.logRequest();
#   OT.Search.ApplyUserGeoLocation();
# </script>
# <!-- Tracking to find out if people are clicking on these links -->
# <script>
#     OT.Common.Analytics.init(
#       jQuery.extend(
#         {"channel":"Tokyo Metropolitan Area","charSet":"UTF-8","eVar16":"ratingssearchuser","eVar24":"All","eVar28":"09:00:00","eVar30":100,"eVar34":"Logged Out","eVar36":"anonymous","eVar39":"Tokyo Metropolitan Area","eVar41":"MetroDTP","eVar43":"multisearchresultpage","eVar47":"listsearcher","eVar50":"multisearchresultpage","eVar57":"WebRedesign_New","eVar72":"tt_no_offers_searchresults","eVar74":"new_architecture_newdesign","events":"event2,event23","pageName":"multisearchresultpage","prop1":"Tokyo Metropolitan Area:search","prop24":"All","prop25":"2016-10-31T09:00:00","prop28":"09:00:00","prop2":"Tokyo Metropolitan Area:search:multi","prop30":100,"prop33":"All","prop35":"searchopentables","prop38":"multisearchresultpage","prop45":"nofpopshown","prop46":"ratingsdisplayed","prop58":"","prop7":"Logged Out"},
#         { prop54: s_getLoadTime() }
#       )
#     );
#
#     </script></body> </html>

# %% [markdown]
# <a id="retrieving-data"></a>
# ### Retrieving data from the HTML page

# %% [markdown]
# ### Open Table
# Let's first find each restaurant name listed on the page we've loaded. How do we find the page location of the restaurant? (Hint: We need to know where in the **HTML** the restaurant element is housed.) In order to find the HTML that renders the restaurant location, we can use Google Chrome's Inspect tool:
#
# > http://www.opentable.com/washington-dc-restaurant-listings
#
# > 1. Visit the URL above.
#
# > 2. Right-click on an element you are interested in, then choose Inspect (in Chrome).
#
# > 3. This will open the Developer Tools and show the HTML used to render the selected page element.
#
# > Throughout this lesson, we will use this method to find tags associated with elements of the page we want to scrape.
#
# See if you can find the restaurant name on the page. Keep in mind there are many restaurants loaded on the page.

# %%
# print the restaurant names
soup.find_all(name='span', attrs={'class':'rest-row-name-text'})
# Out:
# [<span class="rest-row-name-text">1331 Metz</span>,
#  <span class="rest-row-name-text">345 D'Amore</span>,
#  <span class="rest-row-name-text">Est Klocko</span>,
#  <span class="rest-row-name-text">Eius Courts</span>,
#  <span class="rest-row-name-text">Velit Collier</span>,
#  <span class="rest-row-name-text">Akeems</span>,
#  <span class="rest-row-name-text">Curts</span>,
#  <span class="rest-row-name-text">Volkman</span>,
#  <span class="rest-row-name-text">Et</span>,
#  <span class="rest-row-name-text">Laudantium Gerhold</span>,
#  <span class="rest-row-name-text">Veum Highway</span>,
#  <span class="rest-row-name-text">849 Stoltenberg</span>,
#  <span class="rest-row-name-text">Court</span>,
#  <span class="rest-row-name-text">1123 Bernhard</span>,
#  <span class="rest-row-name-text">A Expressway</span>,
#  <span class="rest-row-name-text">Jacobs</span>,
#  <span class="rest-row-name-text">Viaduct</span>,
#  <span class="rest-row-name-text">Explicabo Jones</span>,
#  <span class="rest-row-name-text">Occaecati Bernier</span>,
#  <span class="rest-row-name-text">131 Rohan</span>,
#  <span class="rest-row-name-text">Quia Orchard</span>,
#  <span class="rest-row-name-text">Grady Views</span>,
#  <span class="rest-row-name-text">Beatae Mission</span>,
#  <span class="rest-row-name-text">393 Miller</span>,
#  <span class="rest-row-name-text">Placeat Price</span>,
#  <span class="rest-row-name-text">Hermann Shoal</span>,
#  <span class="rest-row-name-text">Agloe Bar &amp; Grill</span>,
#  <span class="rest-row-name-text">Views</span>,
#  <span class="rest-row-name-text">Estate</span>,
#  <span class="rest-row-name-text">Jaron Turnpike</span>,
#  <span class="rest-row-name-text">Lilys</span>,
#  <span class="rest-row-name-text">Points</span>,
#  <span class="rest-row-name-text">Pats</span>,
#  <span class="rest-row-name-text">Row</span>,
#  <span class="rest-row-name-text">Sheridan Bradtke</span>,
#  <span class="rest-row-name-text">Doyle</span>,
#  <span class="rest-row-name-text">Walter</span>,
#  <span class="rest-row-name-text">Auer</span>,
#  <span class="rest-row-name-text">865 Kihn</span>,
#  <span class="rest-row-name-text">Nam Barrows</span>,
#  <span class="rest-row-name-text">519 Jones</span>,
#  <span class="rest-row-name-text">Optio Points</span>,
#  <span class="rest-row-name-text">White</span>,
#  <span class="rest-row-name-text">Optio Trail</span>,
#  <span class="rest-row-name-text">Esmeralda Adams</span>,
#  <span class="rest-row-name-text">Burg</span>,
#  <span class="rest-row-name-text">891 Block</span>,
#  <span class="rest-row-name-text">Grant Estates</span>,
#  <span class="rest-row-name-text">Wilmas</span>,
#  <span class="rest-row-name-text">Ullam Cassin</span>,
#  <span class="rest-row-name-text">Herman</span>,
#  <span class="rest-row-name-text">Pasquales</span>,
#  <span class="rest-row-name-text">Andrew Kiehn</span>,
#  <span class="rest-row-name-text">Earum Wisozk</span>,
#  <span class="rest-row-name-text">Ward Coves</span>,
#  <span class="rest-row-name-text">Dolorum Murray</span>,
#  <span class="rest-row-name-text">Leanns</span>,
#  <span class="rest-row-name-text">Tod Trail</span>,
#  <span class="rest-row-name-text">Iure Jones</span>,
#  <span class="rest-row-name-text">Omnis Coves</span>,
#  <span class="rest-row-name-text">Reynolds Glens</span>,
#  <span class="rest-row-name-text">Dolor Kling</span>,
#  <span class="rest-row-name-text">Dolorum Junction</span>,
#  <span class="rest-row-name-text">Kemmer</span>,
#  <span class="rest-row-name-text">Aut</span>,
#  <span class="rest-row-name-text">330 Steuber</span>,
#  <span class="rest-row-name-text">Facilis Gerhold</span>,
#  <span class="rest-row-name-text">Amet</span>,
#  <span class="rest-row-name-text">Hoppe</span>,
#  <span class="rest-row-name-text">Katheryns</span>,
#  <span class="rest-row-name-text">Koch Islands</span>,
#  <span class="rest-row-name-text">White</span>,
#  <span class="rest-row-name-text">Forge</span>,
#  <span class="rest-row-name-text">Waynes</span>,
#  <span class="rest-row-name-text">Corwin Spur</span>,
#  <span class="rest-row-name-text">Sequi</span>,
#  <span class="rest-row-name-text">Crossroad</span>,
#  <span class="rest-row-name-text">Sint Fields</span>,
#  <span class="rest-row-name-text">Haven</span>,
#  <span class="rest-row-name-text">Ea Curve</span>,
#  <span class="rest-row-name-text">704 Skiles</span>,
#  <span class="rest-row-name-text">Ut Macejkovic</span>,
#  <span class="rest-row-name-text">Mollitia Camp</span>,
#  <span class="rest-row-name-text">Dolore Reinger</span>,
#  <span class="rest-row-name-text">Riley Rapid</span>,
#  <span class="rest-row-name-text">Officiis Road</span>,
#  <span class="rest-row-name-text">Est Borer</span>,
#  <span class="rest-row-name-text">Enim Spinka</span>,
#  <span class="rest-row-name-text">Springs</span>,
#  <span class="rest-row-name-text">Sunt</span>,
#  <span class="rest-row-name-text">Eum</span>,
#  <span class="rest-row-name-text">Hill</span>,
#  <span class="rest-row-name-text">Lakes</span>,
#  <span class="rest-row-name-text">Road</span>,
#  <span class="rest-row-name-text">999 Rempel</span>,
#  <span class="rest-row-name-text">Aminas</span>,
#  <span class="rest-row-name-text">Nigels</span>,
#  <span class="rest-row-name-text">Et Extensions</span>,
#  <span class="rest-row-name-text">Scottie Lueilwitz</span>,
#  <span class="rest-row-name-text">Crossing</span>]

# %% [markdown]
# It is important to always keep in mind the data types that were returned. Note this is a `list`, and we know that immediately by observing the outer square brackets and commas separating each tag.
#
# Next, **note the elements of the list are `Tag` objects, not strings**. (If they were strings, they would be surrounded by quotes.) The Beautiful Soup authors chose to display a `Tag` object visually as a text representation of the tag and its contents. However, **being an object, it has many methods that we can call on it**.
#
# <a id="retrieving-names"></a>
# #### Retrieving the restaurant names
#
# Now that we found a list of tags containing the restaurant names, let's think how we can loop through them all one-by-one. In the following cell, we'll print out the name (and **only** the clean name, not the rest of the html) of each restaurant.

# %%
# for each element you find, print out the restaurant name
for entry in soup.find_all(name='span', attrs={'class':'rest-row-name-text'}):
    print(entry.text)
# Out:
# 1331 Metz
# 345 D'Amore
# Est Klocko
# Eius Courts
# Velit Collier
# Akeems
# Curts
# Volkman
# Et
# Laudantium Gerhold
# Veum Highway
# 849 Stoltenberg
# Court
# 1123 Bernhard
# A Expressway
# Jacobs
# Viaduct
# Explicabo Jones
# Occaecati Bernier
# 131 Rohan
# Quia Orchard
# Grady Views
# Beatae Mission
# 393 Miller
# Placeat Price
# Hermann Shoal
# Agloe Bar & Grill
# Views
# Estate
# Jaron Turnpike
# Lilys
# Points
# Pats
# Row
# Sheridan Bradtke
# Doyle
# Walter
# Auer
# 865 Kihn
# Nam Barrows
# 519 Jones
# Optio Points
# White
# Optio Trail
# Esmeralda Adams
# Burg
# 891 Block
# Grant Estates
# Wilmas
# Ullam Cassin
# Herman
# Pasquales
# Andrew Kiehn
# Earum Wisozk
# Ward Coves
# Dolorum Murray
# Leanns
# Tod Trail
# Iure Jones
# Omnis Coves
# Reynolds Glens
# Dolor Kling
# Dolorum Junction
# Kemmer
# Aut
# 330 Steuber
# Facilis Gerhold
# Amet
# Hoppe
# Katheryns
# Koch Islands
# White
# Forge
# Waynes
# Corwin Spur
# Sequi
# Crossroad
# Sint Fields
# Haven
# Ea Curve
# 704 Skiles
# Ut Macejkovic
# Mollitia Camp
# Dolore Reinger
# Riley Rapid
# Officiis Road
# Est Borer
# Enim Spinka
# Springs
# Sunt
# Eum
# Hill
# Lakes
# Road
# 999 Rempel
# Aminas
# Nigels
# Et Extensions
# Scottie Lueilwitz
# Crossing

# %% [markdown]
# Great!
#
# <a id="retrieving-locations"></a>
# #### Challenge: Retrieving the restaurant locations
#
# Can you repeat that process for finding the location? For example, barmini by Jose Andres is in the location listed as "Penn Quarter" in our search results.

# %%
# first, see if you can identify the location for all elements -- print it out
soup.find_all('span', {'class':'rest-row-meta--location'})
# Out:
# [<span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Frederique</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Elainaborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Port Letitia</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Roxanestad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Schummville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Doloresburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Jaskolskitown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Crawfordburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">North Dorris</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Schaefertown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Martaville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Robertshaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Jackside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Port Alayna</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Port Viviennebury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Romagueraville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Demetrisshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Kali</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Louisaville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Kodymouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Cheyennemouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Diego</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Lavinia</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Pollichside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Kentonchester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Enidside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Hilpertland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lionelport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Nettie</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Alessiaburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Christiansenville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">McLaughlinville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Simonisfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Cletaview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Lemuel</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Jaquelinside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Modestoshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Corteztown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Terrellmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Fatimashire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Wymanmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">North Cynthiamouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Ewell</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Russelbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Tylerbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">North Jazminland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Elyse</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Durwardside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Runolfssonton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Leuschkechester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Barrowsborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Loisville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Hermannhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Nickmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Runolfssonfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Herzogville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Jess</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Francisport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Joannychester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Brad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Manleybury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Kylie</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Brenna</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Kochfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Trever</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Gushaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Alanborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Zulastad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">North Tracyfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Port Edna</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Binsview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Dorotheatown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">East Bethelberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Bustermouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Wiltonbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Port Shanonmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Martine</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Lake Friedrichville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Mattport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Kutchchester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Ikeview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Leolatown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Darrintown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">West Ted</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">McDermottville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Myaside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Volkmanstad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Tavaresview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Naomiefurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Addisonport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Jazlyn</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Anissabury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">New Domenico</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Chanelle</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">South Marcia</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Jeanneton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Drewshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">North Zulaburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Sipesbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text sfx1388addContent">Jennyferland</span>]

# %%
# now print out EACH location for the restaurants
for entry in soup.find_all('span', {'class':'rest-row-meta--location'}):
    print(entry.text)
# Out:
# South Frederique
# Elainaborough
# Port Letitia
# East Roxanestad
# Schummville
# Doloresburgh
# Jaskolskitown
# Lake Crawfordburgh
# North Dorris
# Schaefertown
# Martaville
# Robertshaven
# New Jackside
# Port Alayna
# Port Viviennebury
# Romagueraville
# Demetrisshire
# East Kali
# South Louisaville
# Kodymouth
# Cheyennemouth
# Lake Diego
# Lake Lavinia
# Pollichside
# Kentonchester
# Enidside
# Hilpertland
# Lionelport
# West Nettie
# Alessiaburgh
# Christiansenville
# McLaughlinville
# Simonisfurt
# Cletaview
# West Lemuel
# South Jaquelinside
# Modestoshire
# Corteztown
# East Terrellmouth
# Lake Fatimashire
# Wymanmouth
# North Cynthiamouth
# New Ewell
# Russelbury
# Tylerbury
# North Jazminland
# East Elyse
# Durwardside
# Runolfssonton
# Leuschkechester
# Barrowsborough
# West Loisville
# West Hermannhaven
# Lake Nickmouth
# Runolfssonfort
# Herzogville
# West Jess
# South Francisport
# Lake Joannychester
# South Brad
# East Manleybury
# New Kylie
# South Brenna
# Kochfurt
# New Trever
# New Gushaven
# New Alanborough
# Zulastad
# North Tracyfurt
# Port Edna
# Binsview
# South Dorotheatown
# East Bethelberg
# Bustermouth
# Wiltonbury
# Port Shanonmouth
# South Martine
# Lake Friedrichville
# Mattport
# Kutchchester
# Ikeview
# South Leolatown
# South Darrintown
# West Ted
# McDermottville
# Myaside
# Volkmanstad
# Tavaresview
# Naomiefurt
# Addisonport
# New Jazlyn
# Anissabury
# New Domenico
# South Chanelle
# South Marcia
# Jeanneton
# Drewshire
# North Zulaburgh
# Sipesbury
# Jennyferland

# %% [markdown]
# <a id="retrieving-prices"></a>
# #### Retrieving the restaurant prices

# %% [markdown]
# Ok, we've figured out the restaurant name and location. Now we need to grab the price (number of dollar signs on a scale of one to four) for each restaurant. We'll follow the same process.

# %%
# print out all prices
soup.find_all('div', {'class':'rest-row-pricing'})
# Out:
# [<div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>]

# %%
# print out EACH number of dollar signs per restaurant
# this one is trickier to eliminate the html. Hint: try a nested find
# print the number of dollars signs per restaurant

for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    price = entry.find('i').text
    print(price.count('$'), "  -->  ", price)
# Out:
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 2   -->     $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 4   -->     $    $    $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 3   -->     $    $    $
# 2   -->     $    $
# 2   -->     $    $
# 4   -->     $    $    $    $
# 4   -->     $    $    $    $

# %% [markdown]
# That looks great, but what if I wanted just the number of dollar signs per restaurant? Can you figure out a way to simply print out the number of dollar signs per restaurant listed?

# %% [markdown]
# ### Craigslist

# %%
html =  requests.get('https://santabarbara.craigslist.org/d/apts-housing-for-rent/search/apa')
soup_cl = BeautifulSoup(html.text, 'html.parser')

# %%
results = soup_cl.find_all('p', attrs={'class': 'result-info'})
listings = []
for result in results:
    result_dict = {}
    result_dict['title'] = result.find('a').text
    result_dict['price'] = result.find('span', attrs={'class': 'result-price'}).text
    listings.append(result_dict)

listings
# Out:
# [{'price': '$2660',
#   'title': 'The Perfect Pool to Jump right into! Arrive Los Carneros!'},
#  {'price': '$1500', 'title': 'Urgently need a home'},
#  {'price': '$3550', 'title': 'THIS PLACE WILL MAKE YOU FEEL RIGHT AT HOME!'},
#  {'price': '$3295', 'title': 'Everything You Need. All Right Here.'},
#  {'price': '$1900', 'title': "Beautiful 1920's Farmhouse for rent"},
#  {'price': '$2100', 'title': 'Gorgeous Upper State Apartment'},
#  {'price': '$3100', 'title': 'Modern, Stylish, Close to West Beach'},
#  {'price': '$2395',
#   'title': '2 Bedroom, 1.5 Bath - Townhouse Apt. - Montecito Gardens Apts'},
#  {'price': '$2760',
#   'title': '2 bedroom 2 bath - Immediate Move in available!'},
#  {'price': '$2100', 'title': 'Gorgeous Upper State Apartment'},
#  {'price': '$1125', 'title': 'Looking for a roommate!'},
#  {'price': '$1250', 'title': '2Bd/1Ba apartment in Lompoc'},
#  {'price': '$2660',
#   'title': 'Last day to receive up to 1 month free! Call now!'},
#  {'price': '$3750', 'title': '5 Bd/3Ba+2 Car garage Duplex in Santa Barbara'},
#  {'price': '$4950', 'title': '4 bedroom, 3 bath'},
#  {'price': '$1395',
#   'title': 'Large Studio Furnished Downtown Walk Everywhere!'},
#  {'price': '$4200', 'title': 'Downtown Stand-Alone Craftsman Cottage'},
#  {'price': '$725',
#   'title': 'Big house on mesa, great for students near SBCC on Cliff Drive'},
#  {'price': '$825',
#   'title': 'Across the street from SBCC, great for students and groups'},
#  {'price': '$2475',
#   'title': 'Start Your Summer Off With A New Apartment Close to the Beach & SBCC'},
#  {'price': '$1825',
#   'title': 'Two units available in beautiful Isla Vista apartment, near UCSB, IV'},
#  {'price': '$2795', 'title': 'Apartments Tailored to Your Highest Standards.'},
#  {'price': '$3072', 'title': '2 BEDROOM 2 BATHROOM! 4 weeks FREE!'},
#  {'price': '$5400',
#   'title': 'Cozy apartment near downtown Santa Barbara, furnished and renovated'},
#  {'price': '$3452', 'title': '2 BEDROOM 2 BATHROOM WITH A DEN! 4 weeks FREE!'},
#  {'price': '$7920',
#   'title': 'House for 10 available in Isla Vista, prime location on Del Playa'},
#  {'price': '$2300', 'title': 'Two bedrooms near SBCC'},
#  {'price': '$4500', 'title': 'Gorgeous HOME in Solvang with Amazing Views'},
#  {'price': '$1950',
#   'title': 'Bright Multi Level Condo in Buellton 2Bd/2Ba+Den'},
#  {'price': '$2450', 'title': 'Gorgeous Remodel above Alcazar Theater'},
#  {'price': '$1925', 'title': 'One Month FREE rent!!!'},
#  {'price': '$7650',
#   'title': 'Spanish-Style Apartment for 10 available on Del Playa, near UCSB, IV'},
#  {'price': '$1695', 'title': 'Apartment near Milpas 1Bd/1BA with a car port'},
#  {'price': '$2175',
#   'title': '$500 SECURITY DEPOSIT!! NEWLY RENOVATED UNIT NEAR DT SB!!'},
#  {'price': '$2800',
#   'title': 'NEWLY RENOVATED W/GATED ENTRY UNIT NEAR DOWNTOWN SB!!!'},
#  {'price': '$1050', 'title': '617 West Ocean #F'},
#  {'price': '$2175',
#   'title': '$500 SECURITY DEPOSIT!! NEWLY RENOVATED UNIT NEAR DT SB!!'},
#  {'price': '$2250',
#   'title': '*LOWER RATES* PEACEFUL LIVING NEAR SBCC AND THE BEACH!!'},
#  {'price': '$695',
#   'title': 'Isla Vista OCEANFRONT remodeled  property to share by UCSB!'},
#  {'price': '$750',
#   'title': 'Need 3 students for Isla Vista OCEANFRONT triple room joining students'},
#  {'price': '$2700',
#   'title': 'Great Upstairs Available August 3rd  $2,700| The Towbes Group'},
#  {'price': '$2660', 'title': 'Last one at this price amazing 1 bedroom!'},
#  {'price': '$2435',
#   'title': '2 Bed / 1 Bath at Sumida Gardens | The Towbes Group'},
#  {'price': '$1800', 'title': 'Happy Canyon Guest House'},
#  {'price': '$2675',
#   'title': 'Great downstairs Available August 3rd  $2,675| The Towbes Group'},
#  {'price': '$2605',
#   'title': 'Great Location Available For Move-In Now!!! $2,605| The Towbes Group'},
#  {'price': '$2450', 'title': 'Buellton 3 bed, 1 bath on large horse ranch'},
#  {'price': '$2500',
#   'title': 'New Construction 1bd/1bth Upstairs Apt. Downtown'},
#  {'price': '$2500',
#   'title': '(Video Tour Available) 1 BD Downtown Apt with Private Deck'},
#  {'price': '$3230',
#   'title': 'Updated 3br, clean, bright, close to State Street'},
#  {'price': '$2050',
#   'title': '1 BD Upper State, Pet friendly w/ Private Patio'},
#  {'price': '$4200', 'title': '4 Bedroom Goleta Home w/ Large Back Yard'},
#  {'price': '$1875',
#   'title': 'Downstairs one bedroom, smoke free environment in a lovely setting.'},
#  {'price': '$370',
#   'title': 'Maintenance Free Living Let Us Do the Work for You!93401'},
#  {'price': '$2050',
#   'title': 'Bradley Garden Apartments! New 2BD/2BA in Orcutt'},
#  {'price': '$2050',
#   'title': 'Bradley Garden Apartments! New 2BD/2BA in Orcutt'},
#  {'price': '$2190', 'title': 'On the Riviera Apt! Furnished-Gardens-'},
#  {'price': '$1500', 'title': '217 South I street'},
#  {'price': '$2495', 'title': 'Townhouse End Unit with Private Garden Patio'},
#  {'price': '$2125',
#   'title': 'Spacious and Renovated One Bedroom Goleta Condo (Pet friendly)'},
#  {'price': '$2495', 'title': 'Townhouse - 2 bedroom, 2 bath - September'},
#  {'price': '$2350', 'title': '2 Bedroom Unit with Balcony - 2 Bed/ 1 Bath'},
#  {'price': '$1700', 'title': 'Downstairs One Bedroom Ellwood Beach'},
#  {'price': '$3450',
#   'title': 'GREAT SAN ROQUE HOME!Hope School district-Walk to everything!3BR / 2BA'},
#  {'price': '$4395', 'title': 'Five Bedroom Two Bath for August in Ellwood'},
#  {'price': '$3235',
#   'title': 'Amazing 2 bedroom with a 1 month credit special!'},
#  {'price': '$3230',
#   'title': '3bedroom 2bath, Spacious, Washer/Dryer Specials!| The Towbes Group'},
#  {'price': '$2910',
#   'title': '2bedroom 2bath, Washer/Dryer Ready, Spacious! | The Towbes Group'},
#  {'price': '$2520',
#   'title': '2bedroom 1bath , Natural Settings,Washer/Dryer! | The Towbes Grounp'},
#  {'price': '$2350', 'title': '2 Bedroom 2 Bath Unit in Ellwood'},
#  {'price': '$5400', 'title': 'Beautiful 5 Bedroom 4 Bath House'},
#  {'price': '$2995',
#   'title': 'Storke Ranch townhouse, patio, pools, spas, gym'},
#  {'price': '$1495',
#   'title': 'New carpet, fresh paint, parking, laundry (jc-13)'},
#  {'price': '$1995',
#   'title': 'Spacious, patio, pool, near UCSB & Goleta Beach  (tl9d)'},
#  {'price': '$1950', 'title': 'Spacious, downtown, bonus room (b1b-b)'},
#  {'price': '$2395',
#   'title': 'View! Walk to beach, new paint & carpet, upstairs (j6h-f)'},
#  {'price': '$2575',
#   'title': 'Reduced! Very big townhouse, beautiful upgrades (r6e-6)'},
#  {'price': '$1850', 'title': 'Large loft, walk in closet, near UCSB (ge-2)'},
#  {'price': '$2475',
#   'title': 'Reduced! New carpet, spacious, 1 block from State Street, big kitchen'},
#  {'price': '$1550',
#   'title': 'Spacious, new carpet, upstairs w/balcony, parking, laundry (ge-15'},
#  {'price': '$3750',
#   'title': 'Large home, patio, fireplace 2 car garage + carport (hs5c)'},
#  {'price': '$2295',
#   'title': 'Near beach, remodeled, some ocean views (j6h-c)'},
#  {'price': '$2195',
#   'title': 'Remodeled kitchen & bath, downstairs, common courtyard (j6h-b)'},
#  {'price': '$2040',
#   'title': 'Ocean view, upstairs with balcony, close to beach (d0o-h)'},
#  {'price': '$1200', 'title': '322 North H #A Commercial'},
#  {'price': '$3420',
#   'title': 'Remodeled, very large, downtown, balcony (cq1a)'},
#  {'price': '$1590',
#   'title': 'Near UCSB & Costco, patio, off st parking, laundry (ge-8)'},
#  {'price': '$1825',
#   'title': 'Downtown, wood floors, w/t/g included,  4 unit building (FM6D-A)'},
#  {'price': '$1825',
#   'title': 'Downtown, close to Alameda park, view of Riviera, W/T/G incl (h4s-10)'},
#  {'price': '$2475',
#   'title': "Near Elings Park, Hendry's Beach, townhouse, patio (cb7s)"},
#  {'price': '$1795',
#   'title': 'Near Cottage Hospital, upstairs, laundry (ja-8)'},
#  {'price': '$2500',
#   'title': 'REMODELED SPACIOUS CONDO NEAR UCSB WITH HEATED POOL & JACUZZI/'},
#  {'price': '$2100', 'title': 'Efficiency studio w/kitchenette'},
#  {'price': '$1980',
#   'title': 'Remodeled 2 singles apt in IV w/ free internet/cable/Water'},
#  {'price': '$2800',
#   'title': 'Large Double + Private Single in IV w/ Free Internet, Cable + Water'},
#  {'price': '$3600',
#   'title': 'Unique 4 person Split Floor Plan (2 Singles + Large Double) IV apts'},
#  {'price': '$3895',
#   'title': '3 BEDROOM, 2.5 BATH TOWNHOUSE AVAILABLE FOR RENT STARTING 9-1-2020'},
#  {'price': '$2200',
#   'title': 'Very Private Tranquil Guesthouse, 1 Bedroom, 1 Bath'},
#  {'price': '$3800',
#   'title': 'Spacious Light & Bright Townhouse, 3 Bedroom 2.5 Bath'},
#  {'price': '$8200',
#   'title': 'Attractive Montecito 4bdrm+Office/3bath home in Cold Springs District'},
#  {'price': '$3250',
#   'title': 'Classic Upper East Spacious Duplex, 2bdrm/2ba (Uppe, 2 Bedroom, 2 Bath'},
#  {'price': '$4800', 'title': '3BR Close to the Beach'},
#  {'price': '$1495', 'title': 'Carriage House 1 Bed Apartment'},
#  {'price': '$2250',
#   'title': 'BEAUTIFUL Light & Bright Topfloor 2 Bedroom Apartment'},
#  {'price': '$2420', 'title': 'Large Recently Redone'},
#  {'price': '$750',
#   'title': 'Home away from home Student Housing, Close to SBCC'},
#  {'price': '$4100', 'title': 'Private 2BR House with Mountain Views'},
#  {'price': '$3235',
#   'title': 'Great experiences are just round the corner! Come see your new home!'},
#  {'price': '$2800', 'title': 'See Virtual Tour. 1/2 BLOCK UCSB.'},
#  {'price': '$4400', 'title': 'Remodeled townhouse one block from SBCC'},
#  {'price': '$3000', 'title': 'WATCH VIDEO TOUR - 1/2 BLOCK TO UCSB'},
#  {'price': '$2895',
#   'title': 'COTTAGE IN DOWNTOWN~~RECENT REMODEL~~NEW PAINT, CARPET & TILE~~'},
#  {'price': '$3500',
#   'title': 'RANCH HOUSE~~FURNISHED~~GATED PROPERTY~~SUPER QUIET~~LIKE NEW~~'},
#  {'price': '$3000', 'title': 'idyllic family home'},
#  {'price': '$3000',
#   'title': "Quiet Goleta North House, Near Trader Joe's, UCSB"},
#  {'price': '$3235', 'title': 'Only 1 left that has 1 month free!!!'},
#  {'price': '$1700',
#   'title': 'Large and amazing one bedroom unit is available for you'},
#  {'price': '$2660',
#   'title': 'Recently lowered pricing! Only a couple left hurry in now!'},
#  {'price': '$1800', 'title': 'unique one bedroom apartment for rent'},
#  {'price': '$1825',
#   'title': 'UCSB GOLETA LARGE DOWNSTAIRS ONE BEDROOM ONE BATH WITH A PATIO'}]

# %% [markdown]
# <a id="selenium"></a>
# ## Introducing Selenium
#
# Selenium is a headless browser. It allows us to render JavaScript just as a human-navigated browser would.
#
# To install Selenium, use one of the following:
# - **Anaconda:** `conda install -c conda-forge selenium`
# - **pip:** `pip install selenium`
#
# You will also need GeckoDriver (this assumes you are using Homebrew for Mac):
#
# - ```brew install geckodriver```

# %%
from selenium import webdriver

# %% [markdown]
# Selenium requires us to determine a default browser to run. I'm going to opt for Chrome. http://selenium-python.readthedocs.io/faq.html
#
# **STOP - What is going to happen when I run the next cell?**

# %%
# create a driver called Firefox
driver = webdriver.Chrome()

# %% [markdown]
# Pretty crazy, right? Let's close that driver.

# %%
# close it
driver.close()

# %%
# let's boot it up, and visit a URL of our choice
driver = webdriver.Chrome()
driver.get("http://www.python.org")

# %% [markdown]
# Awesome. Now we're getting somewhere: programmatically controlling our browser like a human.

# %% [markdown]
# Let's return to our problem at hand. We need to visit the OpenTable listing for DC. Once there, we need to get the html to load. In the next cell, prove you can programmatically visit the page.

# %%
# visit our OpenTable page
driver = webdriver.Chrome()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# always good to check we've got the page we think we do
assert "OpenTable" in driver.title

# %%
driver.title
# Out:
# 'Washington, D.C. Area Restaurants List | OpenTable'

# %%
driver.close()

# %% [markdown]
# <a id="selenium-js"></a>
# ### Running JavaScript before scraping
#
# Now, to resolve our JavaScript problem, there's a few things we can do. What I'll do in this case is request that the page load, wait one second, and then I'm going to grab the source html from the page. Because the page should believe I'm visiting from a live connection on a browser client, the JavaScript should render to be a part of the page source. I can then grab the page source.

# %%
from time import sleep

# %%
# visit our relevant page
driver = webdriver.Chrome()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# wait one second
sleep(1)

#grab the page source
html = driver.page_source

# %% [markdown]
# **Pop Quiz:** What do we need to do with this HTML?

# %%
# BeautifulSoup it!
html = BeautifulSoup(html, "lxml")

# %% [markdown]
# How do we locate bookings on the page?

# %%
# print out the number bookings for all restaurants
html.find_all('div', {'class':'booking'})
# Out:
# [<div class="booking"><span class="tadpole"></span> Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 20 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 58 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 34 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 45 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 90 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 36 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 69 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 16 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 17 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 73 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 255 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 10 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 27 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 29 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 22 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 25 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 16 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 62 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 16 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 39 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 16 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 68 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 17 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 10 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 42 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 4 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 21 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span> Booked 3 times today</div>]

# %%
# grabbing only the text content
for entry in html.find_all('div', {'class':'booking'}):
    print(entry.text)
# Out:
#  Booked 11 times today
#  Booked 20 times today
#  Booked 58 times today
#  Booked 34 times today
#  Booked 12 times today
#  Booked 14 times today
#  Booked 8 times today
#  Booked 11 times today
#  Booked 13 times today
#  Booked 15 times today
#  Booked 15 times today
#  Booked 11 times today
#  Booked 13 times today
#  Booked 45 times today
#  Booked 6 times today
#  Booked 15 times today
#  Booked 12 times today
#  Booked 8 times today
#  Booked 14 times today
#  Booked 5 times today
#  Booked 12 times today
#  Booked 90 times today
#  Booked 36 times today
#  Booked 9 times today
#  Booked 69 times today
#  Booked 16 times today
#  Booked 7 times today
#  Booked 1 times today
#  Booked 3 times today
#  Booked 23 times today
#  Booked 17 times today
#  Booked 1 times today
#  Booked 7 times today
#  Booked 73 times today
#  Booked 255 times today
#  Booked 3 times today
#  Booked 10 times today
#  Booked 1 times today
#  Booked 13 times today
#  Booked 15 times today
#  Booked 13 times today
#  Booked 3 times today
#  Booked 2 times today
#  Booked 27 times today
#  Booked 6 times today
#  Booked 5 times today
#  Booked 13 times today
#  Booked 8 times today
#  Booked 6 times today
#  Booked 9 times today
#  Booked 2 times today
#  Booked 29 times today
#  Booked 13 times today
#  Booked 22 times today
#  Booked 25 times today
#  Booked 1 times today
#  Booked 13 times today
#  Booked 16 times today
#  Booked 62 times today
#  Booked 16 times today
#  Booked 39 times today
#  Booked 16 times today
#  Booked 68 times today
#  Booked 15 times today
#  Booked 11 times today
#  Booked 18 times today
#  Booked 8 times today
#  Booked 8 times today
#  Booked 12 times today
#  Booked 6 times today
#  Booked 17 times today
#  Booked 10 times today
#  Booked 3 times today
#  Booked 5 times today
#  Booked 5 times today
#  Booked 18 times today
#  Booked 8 times today
#  Booked 8 times today
#  Booked 2 times today
#  Booked 42 times today
#  Booked 19 times today
#  Booked 4 times today
#  Booked 9 times today
#  Booked 1 times today
#  Booked 21 times today
#  Booked 1 times today
#  Booked 3 times today
#  Booked 14 times today
#  Booked 6 times today
#  Booked 11 times today
#  Booked 5 times today
#  Booked 2 times today
#  Booked 3 times today
#  Booked 5 times today
#  Booked 3 times today

# %%
driver.close()

# %% [markdown]
# We've succeeded!
#
# <a id="selenium-regex"></a>
# ### Using regex to only get digits
#
# But we can clean this up a little bit. We're going to use regular expressions (regex) to grab only the digits that are available in each of the text.
#
# The best way to get good at regex is to, well, just keep trying and testing: http://pythex.org/

# %%
import re

# %% [markdown]
# Given we haven't covered regex, I'll show you how to use the search function to match any given digit.

# %%
# for each entry, grab the text
for booking in html.find_all('div', {'class':'booking'}):
    # match all digits
    match = re.search(r'\d+', booking.text)
    
    if match:
        # print if found
        print(match.group())
    else:
        # otherwise pass
        pass
# Out:
# 11
# 20
# 58
# 34
# 12
# 14
# 8
# 11
# 13
# 15
# 15
# 11
# 13
# 45
# 6
# 15
# 12
# 8
# 14
# 5
# 12
# 90
# 36
# 9
# 69
# 16
# 7
# 1
# 3
# 23
# 17
# 1
# 7
# 73
# 255
# 3
# 10
# 1
# 13
# 15
# 13
# 3
# 2
# 27
# 6
# 5
# 13
# 8
# 6
# 9
# 2
# 29
# 13
# 22
# 25
# 1
# 13
# 16
# 62
# 16
# 39
# 16
# 68
# 15
# 11
# 18
# 8
# 8
# 12
# 6
# 17
# 10
# 3
# 5
# 5
# 18
# 8
# 8
# 2
# 42
# 19
# 4
# 9
# 1
# 21
# 1
# 3
# 14
# 6
# 11
# 5
# 2
# 3
# 5
# 3

# %% [markdown]
# The above example (and many others) are available in the Selenium docs: http://selenium-python.readthedocs.io/getting-started.html
#
# What is especially important is exploring functionality like locating elements: http://selenium-python.readthedocs.io/locating-elements.html#locating-elements
#
# FAQ:
# http://selenium-python.readthedocs.io/faq.html

# %% [markdown]
# ### Summary
#
# In this lesson, we used the Beautiful Soup library to locate elements on a website then scrape their text. We also used the Selenium headless browser to run JavaScript first before retrieving the page contents.
